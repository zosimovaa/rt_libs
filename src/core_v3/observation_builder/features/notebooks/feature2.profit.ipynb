# %%
import sys
# for local development
RT_LIBS_PATH = "/Users/alex/Dev_projects/MyOwnRepo/rt_libs/src"
BA_LIBS_PATH = "/Users/alex/Dev_projects/MyOwnRepo/basic_application/src"
sys.path.append(RT_LIBS_PATH)
sys.path.append(BA_LIBS_PATH)

# %%
# %matplotlib notebook
db_connect_params = {
    "host" : "194.87.210.189",
    "port" : 59000,
    "user" : "alex",
    "password" : "Xrxcmr758",
    "database" : "rt5"
}

# %%
import time
import cProfile, pstats
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from data_providers import DbDataProviderRT5
from data_providers import ClickHouseConnector

from core.context import BasicContext
from data_point import DataPoint, DataPointFactory
from core_v3.action_controller import ActionControllerDiffReward

from core.observation_builder.precompute import PrecomputeOrderbookDiffFeature

from core.observation_builder.features2 import ProfitFeature2D
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [4], in <cell line: 4>()
#       1 from data_providers import DbDataProviderRT5
#       2 from data_providers import ClickHouseConnector
# ----> 4 from core.context import BasicContext
#       5 from data_point import DataPoint, DataPointFactory
#       6 from core.action_controller import ActionControllerDiffReward
#
# ModuleNotFoundError: No module named 'core'

# %% [markdown]
# ## DatasetDownload

# %%
path_train = "/Users/alex/Dev_projects/RT/model_train/datasets/rt5/03.BTC_USDT-300-train.csv"
path_test = "/Users/alex/Dev_projects/RT/model_train/datasets/rt5/03.BTC_USDT-300-test.csv"
path_test2 = "/Users/alex/Dev_projects/RT/model_train/datasets/rt5/03.BTC_USDT-300-test2.csv"

data_train = pd.read_csv(path_train, index_col='ts')
data_test = pd.read_csv(path_test, index_col='ts')
data_test2 = pd.read_csv(path_test2, index_col='ts')

# %%
try:
    dataset = pd.read_csv("./test_dataset.csv", index_col='ts')
    print("Прочитано из файла")
except FileNotFoundError:
    
    ts = int(time.time())
    period = 60
    total_points = 5000

    pair = "BTC_USDT"


    #----
    with ClickHouseConnector(db_connect_params) as conn:
        data_provider = DbDataProviderRT5(conn)

        dataset = data_provider.get(
                                ts,
                                period,
                                total_points,
                                pair
                            )
    dataset.to_csv("./test_dataset.csv")
    print("Загружен новый датасет")
    
print(dataset.shape)
# Out:
# Прочитано из файла
# (5000, 11)

# %%
dataset
# Out:
#                              dt  lowest_ask  highest_bid  \
# ts
# 1675190531  2023-01-31 21:42:11   23150.770    23134.951
# 1675190591  2023-01-31 21:43:11   23136.010    23131.549
# 1675190651  2023-01-31 21:44:11   23142.900    23138.930
# 1675190711  2023-01-31 21:45:11   23138.960    23138.930
# 1675190771  2023-01-31 21:46:11   23154.030    23149.602
# ...                         ...         ...          ...
# 1675490231  2023-02-04 08:57:11   23305.970    23305.010
# 1675490291  2023-02-04 08:58:11   23315.309    23311.700
# 1675490351  2023-02-04 08:59:11   23318.760    23311.740
# 1675490411  2023-02-04 09:00:11   23318.760    23311.740
# 1675490471  2023-02-04 09:01:11   23316.680    23311.780
#
#                                                          asks  \
# ts
# 1675190531  {'23150.77': 1.082469, '23150.78': 0.092513, '...
# 1675190591  {'23136.01': 1.082488, '23136.02': 0.050858, '...
# 1675190651  {'23142.90': 1.082488, '23142.91': 0.002142, '...
# 1675190711  {'23138.96': 1.082488, '23138.97': 0.027, '231...
# 1675190771  {'23154.03': 0.092126, '23160.37': 0.002124, '...
# ...                                                       ...
# 1675490231  {'23305.97': 0.001243, '23306.00': 0.000711, '...
# 1675490291  {'23315.31': 0.748515, '23315.32': 0.000363, '...
# 1675490351  {'23318.76': 0.748513, '23318.77': 0.001243, '...
# 1675490411  {'23318.76': 0.748513, '23318.77': 0.001243, '...
# 1675490471  {'23316.68': 0.749188, '23316.69': 0.001243, '...
#
#                                                          bids   buy_vol  \
# ts
# 1675190531  {'23134.95': 0.14, '23134.94': 0.033976, '2313...  0.016218
# 1675190591  {'23131.55': 0.033981, '23131.54': 0.43231, '2...  0.012107
# 1675190651  {'23138.93': 0.03397, '23138.92': 0.032715, '2...  0.025996
# 1675190711  {'23138.93': 0.03397, '23138.92': 0.032715, '2...  0.025015
# 1675190771  {'23149.60': 0.14, '23149.59': 0.002101, '2314...  0.017419
# ...                                                       ...       ...
# 1675490231  {'23305.01': 0.240275, '23305.00': 0.14, '2330...  0.032404
# 1675490291  {'23311.70': 0.240569, '23311.69': 0.068322, '...  0.015981
# 1675490351  {'23311.74': 0.240571, '23311.73': 0.092965, '...  0.041824
# 1675490411  {'23311.74': 0.240571, '23311.73': 0.092965, '...  0.006766
# 1675490471  {'23311.78': 0.239896, '23311.77': 0.000122, '...  0.002482
#
#             sell_vol  total_vol  buy_num  sell_num  total_num
# ts
# 1675190531  0.018967   0.035185        2         2          4
# 1675190591  0.029802   0.041909        4         5          9
# 1675190651  0.007660   0.033656        7         3         10
# 1675190711  0.047751   0.072766        6         8         14
# 1675190771  0.017783   0.035202        4         3          7
# ...              ...        ...      ...       ...        ...
# 1675490231  0.012102   0.044506       10         7         17
# 1675490291  0.032724   0.048705       10        10         20
# 1675490351  0.024563   0.066387        9         5         14
# 1675490411  0.020574   0.027340        2         2          4
# 1675490471  0.016003   0.018485        1         4          5
#
# [5000 rows x 11 columns]

# %%
dataset = data_train

# %% [markdown]
# # Context

# %%
dpf = DataPointFactory(dataset, step_size=1, offset=50, observation_len=10, future_points=0)

context = BasicContext()
action_controller = ActionControllerDiffReward(context)
dp = dpf.get_current_step()
context.update_datapoint(dp)

# %% [markdown]
# # Класс фичи

# %%
"""
Module with basic features - deal status, rate, profit.
"""

import logging
import numpy as np
import pandas as pd

from core.observation_builder.features2.abstract_feature import AbstractFeature

logger = logging.getLogger(__name__)


class ProfitFeature2D(AbstractFeature):
    """Profit calculation"""
    def __init__(self, context, step_factor=(1,), scale_output=30):
        super().__init__(context, step_factor=step_factor, scale_output=scale_output)

    def _get(self):
        trade_state = self.context.get("is_open", domain="Trade")
        data_point = self.context.data_point
        trade = self.context.trade
        obs = []
        for sf in self.step_factor:
            if trade_state:
                timestamps = data_point.get_points(step_factor=sf)
                mask = (timestamps > trade.open_ts) & (timestamps <= trade.close_ts)
                current_rates = data_point.get_values("highest_bid", step_factor=sf)
                current_rates = current_rates[sf - 1::sf]
                profit = current_rates / trade.open_price - 1 - trade.market_fee
                profit = profit * mask * self.scale_output
            else:
                profit = np.zeros(data_point.observation_len)

            obs.append(profit.reshape(-1, 1))

        feature = np.concatenate([*obs], axis=1)
        return feature

# %%
"""
Module with basic features - deal status, rate, profit.
"""

import logging
import numpy as np
import pandas as pd

from core.observation_builder.features2.abstract_feature import AbstractFeature

logger = logging.getLogger(__name__)


class ProfitDiffFeature2D(AbstractFeature):
    """Profit calculation"""

    def __init__(self, context, step_factor=(1,), scale_output=100):
        super().__init__(context, step_factor=step_factor, scale_output=scale_output)

    def _get(self):
        trade_state = self.context.get("is_open", domain="Trade")
        data_point = self.context.data_point
        trade = self.context.trade
        obs = []
        for sf in self.step_factor:
            if trade_state:
                timestamps = data_point.get_points(step_factor=sf, num=data_point.observation_len + 1)
                mask = (timestamps > trade.open_ts) & (timestamps <= trade.close_ts)
                current_rates = data_point.get_values("highest_bid", step_factor=sf, num=data_point.observation_len + 1)
                current_rates = current_rates[sf - 1::sf]
                profit = current_rates / trade.open_price - 1 - trade.market_fee
                profit = profit * mask

                profit_diff = np.diff(profit) * self.scale_output

            else:
                profit_diff = np.zeros(data_point.observation_len)

            obs.append(profit_diff.reshape(-1, 1))

        feature = np.concatenate([*obs], axis=1)
        return feature

# %%
import numpy as np
d = np.array([1,2,3,2,5, 6])

np.diff(d).shape
# Out:
# (5,)

# %% [markdown]
# # Perfomance test

# %%
def perfomance_test(dataset):
    dpf = DataPointFactory(dataset, step_size=1, offset=150, observation_len=20, future_points=0)
    dp = dpf.reset()
    done = False
    scale_factor = (1,3)
    
    feature = ProfitFeature2D(context, step_factor=scale_factor, scale_output=1)
    action_controller.apply_action(1)

    while not done:
        dp, done = dpf.get_next_step()
        obs = feature.get()
        
#cProfile.run("perfomance_test(dataset)")

# %%
profiler = cProfile.Profile()
profiler.enable()

perfomance_test(dataset)

profiler.disable()
# Out:
# /Users/alex/Dev_projects/MyOwnRepo/rt_libs/src/core/actions/trade_action.py:41: RuntimeWarning: divide by zero encountered in double_scalars
#   profit = round(highest_bid / self.open_price - 1 - self.market_fee, 5)
# /Users/alex/Dev_projects/MyOwnRepo/rt_libs/src/core/action_controller/trade_controller.py:81: RuntimeWarning: invalid value encountered in double_scalars
#   reward = -profit * self.scale_open

# %%
stats = pstats.Stats(profiler).sort_stats('tottime')
stats.print_stats()
# Out:
#          626609 function calls (623593 primitive calls) in 1.045 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#      1505    0.162    0.000    0.617    0.000 /var/folders/sk/hq18v07n541fcm73_jz_p_k00000gn/T/ipykernel_2449/3023448369.py:19(_get)
#      4517    0.047    0.000    0.244    0.000 /Users/alex/Dev_projects/venvs/env_rt_p39/lib/python3.9/site-packages/pandas/core/indexing.py:834(_getitem_lowerdim)
#    123469    0.047    0.000    0.058    0.000 {built-in method builtins.isinstance}
#      4517    0.035    0.000    0.664    0.000 /Users/alex/Dev_projects/venvs/env_rt_p39/lib/python3.9/site-packages/pandas/core/indexing.py:954(__getitem__)
#      1507    0.034    0.000    0.049    0.000 {method 'get_slice' of 'pandas._libs.internals.BlockManager' objects}
#      3010    0.026    0.000    0.054    0.000 /Users/alex/Dev_projects/venvs/env_rt_p39/lib/python3.9/site-packages/pandas/core/frame.py:3463(__getitem__)
#     18068    0.025    0.000    0.061    0.000 {built-in method builtins.any}
#      1505    0.021    0.000    0.021    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#     13551    0.021    0.000    0.027    0.000 /Users/alex/Dev_projects/venvs/env_rt_p39/lib/python3.9/site-packages/pandas/core/indexing.py:958(<genexpr>)
#      1507    0.019    0.000    0.041    0.000 /Users/alex/Dev_projects/MyOwnRepo/rt_libs/src/data_point/data_point.py:28(__init__)
#      3010    0.019    0.000    0.407    0.000 /Users/alex/Dev_projects/MyOwnRepo/rt_libs/src/data_point/data_point.py:71(get_values)
#     12044    0.018    0.000    0.026    0.000 /Users/alex/Dev_projects/venvs/env_rt_p39/lib/python3.9/site-packages/pandas/core/generic.py:560(_get_axis)
#      1507    0.018    0.000    0.025    0.000 /Users/alex/Dev_projects/venvs/env_rt_p39/lib/python3.9/site-packages/pandas/core/generic.py:5517(__finalize__)
#      7527    0.018    0.000    0.063    0.000 /Users/alex/Dev_projects/venvs/env_rt_p39/lib/python3.9/site-packages/pandas/core/indexing.py:2481(check_deprecated_indexers)
#      1505    0.017    0.000    0.017    0.000 {built-in method numpy.core._multiarray_umath.implement_array_function}
#      1505    0.016    0.000    0.659    0.000 /Users/alex/Dev_projects/MyOwnRepo/rt_libs/src/core/observation_builder/features2/abstract_feature.py:18(get)
#      3010    0.016    0.000    0.126    0.000 /Users/alex/Dev_projects/venvs/env_rt_p39/lib/python3.9/site-packages/pandas/core/indexing.py:1169(_getitem_axis)
#      3010    0.016    0.000    0.244    0.000 /Users/alex/Dev_projects/venvs/env_rt_p39/lib/python3.9/site-packages/pandas/core/indexing.py:1137(_getitem_tuple)
#      1507    0.015    0.000    0.051    0.000 /Users/alex/Dev_projects/venvs/env_rt_p39/lib/python3.9/site-packages/pandas/core/indexing.py:761(_validate_tuple_indexer)
#      1507    0.014    0.000    0.127    0.000 /Users/alex/Dev_projects/venvs/env_rt_p39/lib/python3.9/site-packages/pandas/core/generic.py:3908(_slice)
#      6024    0.012    0.000    0.046    0.000 /Users/alex/Dev_projects/venvs/env_rt_p39/lib/python3.9/site-packages/pandas/core/common.py:105(is_bool_indexer)
#      3010    0.012    0.000    0.013    0.000 /Users/alex/Dev_projects/MyOwnRepo/rt_libs/src/data_point/data_point.py:39(get_points)
#      1507    0.011    0.000    0.364    0.000 /Users/alex/Dev_projects/MyOwnRepo/rt_libs/src/data_point/dp_factory.py:54(get_current_step)
#      1507    0.011    0.000    0.169    0.000 /Users/alex/Dev_projects/venvs/env_rt_p39/lib/python3.9/site-packages/pandas/core/indexing.py:815(_getitem_tuple_same_dim)
#      4517    0.011    0.000    0.032    0.000 /Users/alex/Dev_projects/venvs/env_rt_p39/lib/python3.9/site-packages/pandas/core/indexing.py:777(_is_nested_tuple_indexer)
#      1507    0.011    0.000    0.011    0.000 /Users/alex/Dev_projects/venvs/env_rt_p39/lib/python3.9/site-packages/pandas/core/generic.py:566(_get_block_manager_axis)
#      1507    0.010    0.000    0.262    0.000 /Users/alex/Dev_projects/venvs/env_rt_p39/lib/python3.9/site-packages/pandas/core/indexing.py:1456(_getitem_tuple)
#         1    0.010    0.010    1.045    1.045 /var/folders/sk/hq18v07n541fcm73_jz_p_k00000gn/T/ipykernel_2449/3050916892.py:1(perfomance_test)
#     13551    0.010    0.000    0.013    0.000 /Users/alex/Dev_projects/venvs/env_rt_p39/lib/python3.9/site-packages/pandas/core/indexing.py:2486(<genexpr>)
#     12044    0.010    0.000    0.010    0.000 {pandas._libs.lib.is_list_like}
#      3010    0.009    0.000    0.021    0.000 /Users/alex/Dev_projects/venvs/env_rt_p39/lib/python3.9/site-packages/pandas/core/indexing.py:1023(_is_scalar_access)
#      3010    0.009    0.000    0.021    0.000 /Users/alex/Dev_projects/venvs/env_rt_p39/lib/python3.9/site-packages/pandas/core/internals/managers.py:1844(external_values)
#     16561    0.009    0.000    0.009    0.000 /Users/alex/Dev_projects/venvs/env_rt_p39/lib/python3.9/site-packages/pandas/core/generic.py:546(_get_axis_number)
#      1507    0.009    0.000    0.013    0.000 /Users/alex/Dev_projects/venvs/env_rt_p39/lib/python3.9/site-packages/pandas/core/generic.py:239(__init__)
#      3010    0.009    0.000    0.070    0.000 /Users/alex/Dev_projects/venvs/env_rt_p39/lib/python3.9/site-packages/pandas/core/generic.py:3722(xs)
#      1507    0.008    0.000    0.146    0.000 /Users/alex/Dev_projects/venvs/env_rt_p39/lib/python3.9/site-packages/pandas/core/indexing.py:1524(_get_slice_axis)
#     13555    0.008    0.000    0.011    0.000 /Users/alex/Dev_projects/venvs/env_rt_p39/lib/python3.9/site-packages/pandas/core/dtypes/generic.py:43(_check)
#     13551    0.008    0.000    0.009    0.000 /Users/alex/Dev_projects/venvs/env_rt_p39/lib/python3.9/site-packages/pandas/core/indexing.py:2497(<genexpr>)
# 19590/16574    0.007    0.000    0.010    0.000 {built-in method builtins.len}
#      9034    0.007    0.000    0.015    0.000 /Users/alex/Dev_projects/venvs/env_rt_p39/lib/python3.9/site-packages/pandas/core/indexing.py:2454(is_label_like)
#      1505    0.007    0.000    0.371    0.000 /Users/alex/Dev_projects/MyOwnRepo/rt_libs/src/data_point/dp_factory.py:65(get_next_step)
#      1507    0.007    0.000    0.010    0.000 /Users/alex/Dev_projects/venvs/env_rt_p39/lib/python3.9/site-packages/pandas/core/indexes/base.py:654(_simple_new)
#      3014    0.007    0.000    0.011    0.000 /Users/alex/Dev_projects/venvs/env_rt_p39/lib/python3.9/site-packages/pandas/core/indexes/base.py:5023(__getitem__)
#      3010    0.007    0.000    0.007    0.000 {pandas._libs.lib.is_scalar}
#      3010    0.007    0.000    0.008    0.000 /Users/alex/Dev_projects/venvs/env_rt_p39/lib/python3.9/site-packages/pandas/core/frame.py:3923(_get_item_cache)
#      3010    0.007    0.000    0.007    0.000 /Users/alex/Dev_projects/venvs/env_rt_p39/lib/python3.9/site-packages/pandas/core/indexing.py:267(loc)
#      3010    0.006    0.000    0.007    0.000 /Users/alex/Dev_projects/venvs/env_rt_p39/lib/python3.9/site-packages/pandas/core/indexes/base.py:4973(__contains__)
#      1507    0.006    0.000    0.011    0.000 /Users/alex/Dev_projects/venvs/env_rt_p39/lib/python3.9/site-packages/pandas/core/indexing.py:1419(_is_scalar_access)
#     13551    0.006    0.000    0.010    0.000 /Users/alex/Dev_projects/venvs/env_rt_p39/lib/python3.9/site-packages/pandas/core/indexing.py:783(<genexpr>)
#      3010    0.006    0.000    0.006    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#      1505    0.006    0.000    0.023    0.000 <__array_function__ internals>:2(concatenate)
#     12044    0.006    0.000    0.008    0.000 /Users/alex/Dev_projects/venvs/env_rt_p39/lib/python3.9/site-packages/pandas/core/common.py:346(apply_if_callable)
#      4517    0.005    0.000    0.005    0.000 /Users/alex/Dev_projects/venvs/env_rt_p39/lib/python3.9/site-packages/pandas/core/frame.py:804(axes)
#     13551    0.005    0.000    0.007    0.000 /Users/alex/Dev_projects/venvs/env_rt_p39/lib/python3.9/site-packages/pandas/core/indexing.py:957(<genexpr>)
#      3010    0.005    0.000    0.075    0.000 /Users/alex/Dev_projects/venvs/env_rt_p39/lib/python3.9/site-packages/pandas/core/indexing.py:1151(_get_label)
#      6024    0.005    0.000    0.006    0.000 /Users/alex/Dev_projects/venvs/env_rt_p39/lib/python3.9/site-packages/pandas/core/common.py:297(is_null_slice)
#      6020    0.005    0.000    0.008    0.000 /Users/alex/Dev_projects/venvs/env_rt_p39/lib/python3.9/site-packages/pandas/core/indexers/utils.py:69(is_list_like_indexer)
#      4517    0.005    0.000    0.014    0.000 /Users/alex/Dev_projects/venvs/env_rt_p39/lib/python3.9/site-packages/pandas/core/indexing.py:740(_expand_ellipsis)
#      3010    0.005    0.000    0.012    0.000 /Users/alex/Dev_projects/venvs/env_rt_p39/lib/python3.9/site-packages/pandas/core/internals/blocks.py:209(external_values)
#      6024    0.005    0.000    0.005    0.000 /Users/alex/Dev_projects/venvs/env_rt_p39/lib/python3.9/site-packages/pandas/core/generic.py:660(ndim)
#      1507    0.005    0.000    0.018    0.000 /Users/alex/Dev_projects/venvs/env_rt_p39/lib/python3.9/site-packages/pandas/core/frame.py:587(__init__)
#      1507    0.005    0.000    0.015    0.000 /Users/alex/Dev_projects/venvs/env_rt_p39/lib/python3.9/site-packages/pandas/core/indexes/base.py:5071(_getitem_slice)
#      6024    0.004    0.000    0.006    0.000 /Users/alex/Dev_projects/venvs/env_rt_p39/lib/python3.9/site-packages/pandas/core/indexing.py:804(_validate_key_length)
#     15067    0.004    0.000    0.005    0.000 {built-in method builtins.getattr}
#      3010    0.004    0.000    0.007    0.000 /Users/alex/Dev_projects/venvs/env_rt_p39/lib/python3.9/site-packages/pandas/core/internals/blocks.py:2239(external_values)
#      3010    0.004    0.000    0.025    0.000 /Users/alex/Dev_projects/venvs/env_rt_p39/lib/python3.9/site-packages/pandas/core/series.py:645(values)
#      3014    0.004    0.000    0.030    0.000 /Users/alex/Dev_projects/venvs/env_rt_p39/lib/python3.9/site-packages/pandas/core/indexing.py:1343(_validate_key)
#      1507    0.004    0.000    0.004    0.000 /Users/alex/Dev_projects/venvs/env_rt_p39/lib/python3.9/site-packages/pandas/core/flags.py:83(allows_duplicate_labels)
#     13551    0.004    0.000    0.004    0.000 /Users/alex/Dev_projects/venvs/env_rt_p39/lib/python3.9/site-packages/pandas/core/indexing.py:745(<genexpr>)
#      1507    0.004    0.000    0.007    0.000 /Users/alex/Dev_projects/venvs/env_rt_p39/lib/python3.9/site-packages/pandas/core/generic.py:3925(_set_is_copy)
#      1515    0.003    0.000    0.004    0.000 /Users/alex/Dev_projects/MyOwnRepo/rt_libs/src/core/context/basic_context.py:51(get)
#      1507    0.003    0.000    0.007    0.000 /Users/alex/Dev_projects/venvs/env_rt_p39/lib/python3.9/site-packages/pandas/core/indexes/base.py:3999(_validate_positional_slice)
#      1508    0.003    0.000    0.010    0.000 /Users/alex/Dev_projects/venvs/env_rt_p39/lib/python3.9/site-packages/pandas/core/frame.py:821(shape)
#      1507    0.003    0.000    0.152    0.000 /Users/alex/Dev_projects/venvs/env_rt_p39/lib/python3.9/site-packages/pandas/core/indexing.py:1487(_getitem_axis)
#      1507    0.003    0.000    0.003    0.000 /Users/alex/Dev_projects/venvs/env_rt_p39/lib/python3.9/site-packages/pandas/core/flags.py:47(__init__)
#      1507    0.003    0.000    0.003    0.000 /Users/alex/Dev_projects/venvs/env_rt_p39/lib/python3.9/site-packages/pandas/core/generic.py:5577(__setattr__)
#      4517    0.003    0.000    0.003    0.000 /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/contextlib.py:376(__init__)
#     15054    0.003    0.000    0.003    0.000 {pandas._libs.lib.is_iterator}
#      1507    0.003    0.000    0.003    0.000 /Users/alex/Dev_projects/venvs/env_rt_p39/lib/python3.9/site-packages/pandas/core/frame.py:578(_constructor)
#      3010    0.003    0.000    0.003    0.000 /Users/alex/Dev_projects/MyOwnRepo/rt_libs/src/data_point/data_point.py:54(get_indexes)
#      6024    0.003    0.000    0.009    0.000 /Users/alex/Dev_projects/venvs/env_rt_p39/lib/python3.9/site-packages/pandas/core/dtypes/inference.py:184(is_array_like)
#     12044    0.003    0.000    0.003    0.000 {built-in method builtins.callable}
#      3014    0.003    0.000    0.003    0.000 /Users/alex/Dev_projects/venvs/env_rt_p39/lib/python3.9/site-packages/pandas/core/indexing.py:130(iloc)
#      1505    0.003    0.000    0.025    0.000 {method 'sum' of 'numpy.ndarray' objects}
#      4521    0.002    0.000    0.003    0.000 /Users/alex/Dev_projects/venvs/env_rt_p39/lib/python3.9/site-packages/pandas/core/indexes/base.py:6299(_validate_indexer)
#      3010    0.002    0.000    0.004    0.000 /Users/alex/Dev_projects/venvs/env_rt_p39/lib/python3.9/site-packages/pandas/core/indexing.py:1001(_validate_key)
#      3014    0.002    0.000    0.003    0.000 /Users/alex/Dev_projects/venvs/env_rt_p39/lib/python3.9/site-packages/pandas/core/common.py:160(cast_scalar_indexer)
#      3016    0.002    0.000    0.003    0.000 /Users/alex/Dev_projects/venvs/env_rt_p39/lib/python3.9/site-packages/pandas/core/indexes/base.py:884(__len__)
#      3010    0.002    0.000    0.003    0.000 /Users/alex/Dev_projects/venvs/env_rt_p39/lib/python3.9/site-packages/pandas/core/dtypes/inference.py:321(is_hashable)
#      7535    0.002    0.000    0.002    0.000 {pandas._libs.lib.is_integer}
#      4517    0.002    0.000    0.002    0.000 /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/contextlib.py:382(__exit__)
#      3014    0.002    0.000    0.002    0.000 /Users/alex/Dev_projects/venvs/env_rt_p39/lib/python3.9/site-packages/pandas/core/indexing.py:1432(<genexpr>)
#      6040    0.002    0.000    0.002    0.000 {method 'get' of 'dict' objects}
#      6020    0.002    0.000    0.002    0.000 {built-in method builtins.hash}
#      1505    0.002    0.000    0.023    0.000 /Users/alex/Dev_projects/venvs/env_rt_p39/lib/python3.9/site-packages/numpy/core/_methods.py:46(_sum)
#      4517    0.002    0.000    0.002    0.000 /Users/alex/Dev_projects/venvs/env_rt_p39/lib/python3.9/site-packages/pandas/core/indexes/base.py:4786(values)
#      6020    0.001    0.000    0.001    0.000 {pandas._libs.lib.item_from_zerodim}
#      1507    0.001    0.000    0.001    0.000 {built-in method __new__ of type object at 0x10d81dd58}
#      1507    0.001    0.000    0.001    0.000 /Users/alex/Dev_projects/venvs/env_rt_p39/lib/python3.9/site-packages/pandas/core/indexes/base.py:834(_reset_identity)
#      1507    0.001    0.000    0.001    0.000 /Users/alex/Dev_projects/venvs/env_rt_p39/lib/python3.9/site-packages/pandas/core/generic.py:328(attrs)
#      3014    0.001    0.000    0.001    0.000 /Users/alex/Dev_projects/venvs/env_rt_p39/lib/python3.9/site-packages/pandas/core/generic.py:349(flags)
#      1507    0.001    0.000    0.001    0.000 /Users/alex/Dev_projects/venvs/env_rt_p39/lib/python3.9/site-packages/pandas/core/indexing.py:2468(need_slice)
#      3010    0.001    0.000    0.001    0.000 {method 'append' of 'list' objects}
#      1507    0.001    0.000    0.002    0.000 {built-in method builtins.all}
#      4517    0.001    0.000    0.001    0.000 /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/contextlib.py:379(__enter__)
#         2    0.001    0.000    0.001    0.000 {method 'readline' of '_io.BufferedReader' objects}
#      3010    0.001    0.000    0.001    0.000 /Users/alex/Dev_projects/venvs/env_rt_p39/lib/python3.9/site-packages/pandas/core/base.py:326(ndim)
#      3014    0.001    0.000    0.001    0.000 {pandas._libs.lib.is_float}
#      1507    0.001    0.000    0.001    0.000 /Users/alex/Dev_projects/venvs/env_rt_p39/lib/python3.9/site-packages/pandas/core/internals/managers.py:919(__init__)
#         1    0.001    0.001    0.001    0.001 {built-in method posix.urandom}
#      1507    0.001    0.000    0.001    0.000 /Users/alex/Dev_projects/venvs/env_rt_p39/lib/python3.9/site-packages/pandas/core/flags.py:51(allows_duplicate_labels)
#         2    0.001    0.000    0.001    0.000 {built-in method io.open}
#      1505    0.001    0.000    0.001    0.000 /Users/alex/Dev_projects/venvs/env_rt_p39/lib/python3.9/site-packages/numpy/core/multiarray.py:148(concatenate)
#         2    0.000    0.000    0.000    0.000 {method 'readlines' of '_io._IOBase' objects}
#         2    0.000    0.000    0.000    0.000 {built-in method posix.stat}
#      1507    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#         3    0.000    0.000    0.000    0.000 {built-in method builtins.round}
#         3    0.000    0.000    0.002    0.001 /Users/alex/Dev_projects/MyOwnRepo/rt_libs/src/core/actions/trade_action.py:37(get_profit)
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.compile}
#         1    0.000    0.000    0.000    0.000 /Users/alex/Dev_projects/venvs/env_rt_p39/lib/python3.9/site-packages/zmq/sugar/socket.py:540(send)
#         2    0.000    0.000    0.000    0.000 /Users/alex/Dev_projects/venvs/env_rt_p39/lib/python3.9/site-packages/ipykernel/iostream.py:525(write)
#         2    0.000    0.000    0.001    0.001 /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/tokenize.py:388(open)
#         1    0.000    0.000    0.004    0.004 /Users/alex/Dev_projects/MyOwnRepo/rt_libs/src/core/action_controller/trade_controller.py:68(_action_open)
#         2    0.000    0.000    0.002    0.001 /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/linecache.py:80(updatecache)
#         2    0.000    0.000    0.002    0.001 /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/warnings.py:35(_formatwarnmsg_impl)
#         2    0.000    0.000    0.001    0.000 /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/tokenize.py:295(detect_encoding)
#         2    0.000    0.000    0.000    0.000 {method '__exit__' of '_io._IOBase' objects}
#         6    0.000    0.000    0.000    0.000 {built-in method _codecs.utf_8_decode}
#         2    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/warnings.py:403(__init__)
#         1    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/uuid.py:138(__init__)
#         6    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/codecs.py:319(decode)
#         2    0.000    0.000    0.002    0.001 /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/linecache.py:36(getlines)
#         2    0.000    0.000    0.000    0.000 /Users/alex/Dev_projects/venvs/env_rt_p39/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3214(_update_code_co_name)
#         4    0.000    0.000    0.000    0.000 {method 'match' of 're.Pattern' objects}
#         1    0.000    0.000    0.001    0.001 /Users/alex/Dev_projects/MyOwnRepo/rt_libs/src/core/actions/trade_action.py:11(__init__)
#         1    0.000    0.000    0.001    0.001 /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/uuid.py:713(uuid4)
#         1    0.000    0.000    0.000    0.000 /Users/alex/Dev_projects/venvs/env_rt_p39/lib/python3.9/site-packages/ipykernel/iostream.py:209(schedule)
#         2    0.000    0.000    0.003    0.001 /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/warnings.py:20(_showwarnmsg_impl)
#         2    0.000    0.000    0.001    0.000 /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/tokenize.py:319(read_or_stop)
#         1    0.000    0.000    0.000    0.000 /Users/alex/Dev_projects/MyOwnRepo/rt_libs/src/data_point/dp_factory.py:20(__init__)
#         4    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/dis.py:449(findlinestarts)
#         1    0.000    0.000    0.001    0.001 /Users/alex/Dev_projects/MyOwnRepo/rt_libs/src/core/actions/base_action.py:6(__init__)
#         2    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/codeop.py:142(__call__)
#         1    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/uuid.py:279(__str__)
#         2    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/tokenize.py:325(find_cookie)
#         2    0.000    0.000    1.045    0.522 /Users/alex/Dev_projects/venvs/env_rt_p39/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3361(run_code)
#         1    0.000    0.000    0.000    0.000 /Users/alex/Dev_projects/MyOwnRepo/rt_libs/src/core/actions/trade_action.py:25(close)
#         2    0.000    0.000    0.002    0.001 /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/linecache.py:26(getline)
#         1    0.000    0.000    0.000    0.000 /Users/alex/Dev_projects/MyOwnRepo/rt_libs/src/core/context/basic_context.py:64(update_trade)
#         1    0.000    0.000    0.004    0.004 /Users/alex/Dev_projects/MyOwnRepo/rt_libs/src/core/action_controller/trade_controller.py:52(apply_action)
#         1    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/threading.py:1126(is_alive)
#         2    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/contextlib.py:86(__init__)
#         2    0.000    0.000    0.002    0.001 /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/warnings.py:117(_formatwarnmsg)
#         2    0.000    0.000    0.000    0.000 /Users/alex/Dev_projects/venvs/env_rt_p39/lib/python3.9/site-packages/ipykernel/iostream.py:436(_is_master_process)
#         2    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/codecs.py:309(__init__)
#         1    0.000    0.000    1.045    1.045 /var/folders/sk/hq18v07n541fcm73_jz_p_k00000gn/T/ipykernel_2449/1630976001.py:4(<cell line: 4>)
#         2    0.000    0.000    0.003    0.001 /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/warnings.py:96(_showwarnmsg)
#         1    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/threading.py:1059(_wait_for_tstate_lock)
#         2    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/contextlib.py:114(__enter__)
#         2    0.000    0.000    0.000    0.000 /Users/alex/Dev_projects/venvs/env_rt_p39/lib/python3.9/site-packages/ipykernel/iostream.py:455(_schedule_flush)
#         4    0.000    0.000    0.000    0.000 /Users/alex/Dev_projects/venvs/env_rt_p39/lib/python3.9/site-packages/IPython/core/compilerop.py:174(extra_flags)
#         1    0.000    0.000    0.000    0.000 /var/folders/sk/hq18v07n541fcm73_jz_p_k00000gn/T/ipykernel_2449/1630976001.py:6(<cell line: 6>)
#         3    0.000    0.000    0.000    0.000 /Users/alex/Dev_projects/MyOwnRepo/rt_libs/src/core/context/basic_context.py:45(set)
#         1    0.000    0.000    0.000    0.000 /Users/alex/Dev_projects/venvs/env_rt_p39/lib/python3.9/site-packages/ipykernel/iostream.py:97(_event_pipe)
#         1    0.000    0.000    0.000    0.000 /var/folders/sk/hq18v07n541fcm73_jz_p_k00000gn/T/ipykernel_2449/3023448369.py:16(__init__)
#         2    0.000    0.000    0.000    0.000 {method 'write' of '_io.StringIO' objects}
#         6    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#         2    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/contextlib.py:123(__exit__)
#         2    0.000    0.000    0.000    0.000 {method 'startswith' of 'bytes' objects}
#         2    0.000    0.000    0.000    0.000 {method 'seek' of '_io.BufferedReader' objects}
#         2    0.000    0.000    1.045    0.522 {built-in method builtins.exec}
#         2    0.000    0.000    0.000    0.000 {method 'startswith' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/contextlib.py:261(helper)
#         2    0.000    0.000    0.001    0.000 /Users/alex/Dev_projects/MyOwnRepo/rt_libs/src/data_point/dp_factory.py:44(reset)
#         1    0.000    0.000    0.000    0.000 /Users/alex/Dev_projects/MyOwnRepo/rt_libs/src/core/context/basic_context.py:78(set_trade)
#         2    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/codecs.py:260(__init__)
#         2    0.000    0.000    0.000    0.000 /Users/alex/Dev_projects/venvs/env_rt_p39/lib/python3.9/site-packages/traitlets/traitlets.py:672(__get__)
#         2    0.000    0.000    0.000    0.000 {method 'endswith' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 {method 'decode' of 'bytes' objects}
#         2    0.000    0.000    0.000    0.000 {method 'replace' of 'code' objects}
#         2    0.000    0.000    0.000    0.000 /Users/alex/Dev_projects/venvs/env_rt_p39/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3312(compare)
#         1    0.000    0.000    0.000    0.000 /Users/alex/Dev_projects/MyOwnRepo/rt_libs/src/core/observation_builder/features2/abstract_feature.py:12(__init__)
#         1    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method from_bytes}
#         2    0.000    0.000    0.000    0.000 /Users/alex/Dev_projects/venvs/env_rt_p39/lib/python3.9/site-packages/traitlets/traitlets.py:640(get)
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#         2    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.RLock' objects}
#         2    0.000    0.000    0.000    0.000 {method 'strip' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 /Users/alex/Dev_projects/venvs/env_rt_p39/lib/python3.9/site-packages/IPython/core/interactiveshell.py:1191(user_global_ns)
#         1    0.000    0.000    0.000    0.000 {method 'count' of 'list' objects}
#         2    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#         1    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/threading.py:529(is_set)
#         1    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}

# %% [markdown]
# # Оценка распределения

# %%
dataset = data_test

done = False

dpf = DataPointFactory(dataset, step_size=1, offset=460, observation_len=20, future_points=0)
context = BasicContext()
step_factor = (1,3,5)
feature = ProfitFeature2D(context, step_factor=step_factor, scale_output=30)

dp = dpf.get_current_step()
context.update_datapoint(dp)
    
action_controller = ActionControllerDiffReward(context)

results = {}
num = 200
i = 0


while not done:
    dp, done = dpf.get_next_step()
    context.update_datapoint(dp)
    
    
    trade_is_open = context.get("is_open", domain="Trade")
    if i % num ==0:
        if trade_is_open:
            action_controller.apply_action(3)
        else:
            action_controller.apply_action(1)
    
    
    if trade_is_open:
        obs = feature.get()

        for sf_id in range(len(step_factor)):
            values = obs[:, sf_id]

            key_sf = f"sf-{step_factor[sf_id]}"
            if key_sf not in results:
                results[key_sf] = values
            else:
                results[key_sf] = np.concatenate([results[key_sf], values])
            
    i = i + 1

# %%
fig, ax = plt.subplots(figsize=(16,5), ncols=len(step_factor), nrows=1)

for sf_id in range(len(step_factor)):
    key_sf = f"sf-{step_factor[sf_id]}"
    values = results[key_sf]
    ax[sf_id].hist(values, bins=100)
    ax[sf_id].title.set_text(key_sf)
# Out:
# <img src="data:image/png;base64,..." width="1600">

# %%
feature = ProfitFeature2D(context, step_factor=(1,2,3))

# %%
obs = feature.get()
obs
# Out:
# array([[-0.00126779, -0.01837254, -0.0223732 ],
#        [-0.00129819, -0.01087517, -0.02477864],
#        [-0.00110984, -0.00127643, -0.01257718],
#        [-0.0011307 , -0.00120401, -0.00128369],
#        [ 0.        , -0.00056535, -0.00074685]], dtype=float32)

# %%
current_rate = dp.get_value("highest_bid").values[0]
current_rate
# Out:
# 23421.07

# %% [markdown]
# ## sf=1

# %%
dp.data.loc[1675453069:1675453309, "highest_bid"]/current_rate - 1
# Out:
# ts
# 1675453069   -0.000127
# 1675453129   -0.000130
# 1675453189   -0.000111
# 1675453249   -0.000113
# 1675453309    0.000000
# Name: highest_bid, dtype: float32

# %% [markdown]
# ## sf=2

# %%
obs = feature.get()
obs
# Out:
# array([[-0.00126779, -0.01837254, -0.0223732 ],
#        [-0.00129819, -0.01087517, -0.02477864],
#        [-0.00110984, -0.00127643, -0.01257718],
#        [-0.0011307 , -0.00120401, -0.00128369],
#        [ 0.        , -0.00056535, -0.00074685]], dtype=float32)

# %%
dp.data.tail(10)
# Out:
#                             dt    lowest_ask   highest_bid  \
# ts
# 1675452769 2023-02-03 22:32:49  23373.021484  23372.439453
# 1675452829 2023-02-03 22:33:49  23396.960938  23383.640625
# 1675452889 2023-02-03 22:34:49  23409.289062  23399.189453
# 1675452949 2023-02-03 22:35:49  23404.089844  23392.009766
# 1675453009 2023-02-03 22:36:49  23424.550781  23418.060547
# 1675453069 2023-02-03 22:37:49  23424.910156  23418.101562
# 1675453129 2023-02-03 22:38:49  23430.929688  23418.029297
# 1675453189 2023-02-03 22:39:49  23424.380859  23418.470703
# 1675453249 2023-02-03 22:40:49  23428.791016  23418.421875
# 1675453309 2023-02-03 22:41:49  23423.179688  23421.070312
#
#                                                          asks  \
# ts
# 1675452769  {'23373.02': 0.00035, '23378.43': 0.000379, '2...
# 1675452829  {'23396.96': 0.355256, '23396.97': 0.002065, '...
# 1675452889  {'23409.29': 0.373047, '23409.30': 0.002066, '...
# 1675452949  {'23404.09': 0.35958, '23404.10': 0.002056, '2...
# 1675453009  {'23424.55': 0.359278, '23424.56': 0.002097, '...
# 1675453069  {'23424.91': 0.359278, '23424.92': 0.002107, '...
# 1675453129  {'23430.93': 0.359625, '23430.94': 0.001289, '...
# 1675453189  {'23424.38': 0.001333, '23432.74': 0.002122, '...
# 1675453249  {'23428.79': 0.354612, '23428.80': 0.001272, '...
# 1675453309  {'23423.18': 0.001258, '23423.69': 0.363897, '...
#
#                                                          bids   buy_vol  \
# ts
# 1675452769  {'23372.44': 0.702901, '23372.43': 0.14, '2337...  0.023718
# 1675452829  {'23383.64': 0.674272, '23383.63': 0.001246, '...  0.015210
# 1675452889  {'23399.19': 0.14, '23399.18': 0.104425, '2339...  0.013877
# 1675452949  {'23392.01': 0.669712, '23392.00': 0.14, '2339...  0.008706
# 1675453009  {'23418.06': 0.66927, '23418.05': 0.059953, '2...  0.036118
# 1675453069  {'23418.10': 0.669269, '23418.09': 0.14, '2341...  0.021893
# 1675453129  {'23418.03': 0.669271, '23418.02': 0.09179, '2...  0.012593
# 1675453189  {'23418.47': 0.815634, '23418.44': 0.14, '2341...  0.044688
# 1675453249  {'23418.42': 0.673928, '23418.41': 0.640521, '...  0.017010
# 1675453309  {'23421.07': 0.664566, '23421.06': 0.004924, '...  0.000000
#
#             sell_vol  total_vol  buy_num  sell_num  total_num
# ts
# 1675452769  0.028416   0.052134        7         6         13
# 1675452829  0.016324   0.031534        3         7         10
# 1675452889  0.021983   0.035860        3         4          7
# 1675452949  0.019148   0.027854        3         3          6
# 1675453009  0.002416   0.038534        3         2          5
# 1675453069  0.000513   0.022406        3         1          4
# 1675453129  0.015364   0.027957        2         2          4
# 1675453189  0.008411   0.053099        9         4         13
# 1675453249  0.033221   0.050231        7         8         15
# 1675453309  0.006402   0.006402        0         2          2

# %%
avg = 23419.7459
avg/current_rate-1
# Out:
# -5.6547906749249144e-05

# %%
avg = 23418.25
avg/current_rate-1
# Out:
# -0.00012041774617344014
