# %%
import sys
# for local development
RT_LIBS_PATH = "/Users/alex/Dev_projects/MyOwnRepo/rt_libs/src"
BA_LIBS_PATH = "/Users/alex/Dev_projects/MyOwnRepo/basic_application/src"
sys.path.append(RT_LIBS_PATH)
sys.path.append(BA_LIBS_PATH)

# %%
# %matplotlib notebook
db_connect_params = {
    "host" : "194.87.210.189",
    "port" : 59000,
    "user" : "alex",
    "password" : "Xrxcmr758",
    "database" : "rt5"
}

# %%
import time
import cProfile, pstats
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from data_providers import DbDataProviderRT5
from data_providers import ClickHouseConnector

from core.context import BasicContext
from data_point import DataPoint, DataPointFactory
from core.action_controller import ActionControllerDiffReward

from core.observation_builder.precompute import PrecomputeOrderbookDiffFeature

from core.observation_builder.features2 import ProfitFeature2D

# %% [markdown]
# ## DatasetDownload

# %%
path_train = "/Users/alex/Dev_projects/RT/model_train/datasets/rt5/03.BTC_USDT-300-train.csv"
path_test = "/Users/alex/Dev_projects/RT/model_train/datasets/rt5/03.BTC_USDT-300-test.csv"
path_test2 = "/Users/alex/Dev_projects/RT/model_train/datasets/rt5/03.BTC_USDT-300-test2.csv"

data_train = pd.read_csv(path_train, index_col='ts')
data_test = pd.read_csv(path_test, index_col='ts')
data_test2 = pd.read_csv(path_test2, index_col='ts')

# %%
try:
    dataset = pd.read_csv("./test_dataset.csv", index_col='ts')
    print("Прочитано из файла")
except FileNotFoundError:
    
    ts = int(time.time())
    period = 60
    total_points = 5000

    pair = "BTC_USDT"


    #----
    with ClickHouseConnector(db_connect_params) as conn:
        data_provider = DbDataProviderRT5(conn)

        dataset = data_provider.get(
                                ts,
                                period,
                                total_points,
                                pair
                            )
    dataset.to_csv("./test_dataset.csv")
    print("Загружен новый датасет")
    
print(dataset.shape)
# Out:
# Прочитано из файла
# (5000, 11)

# %%
dataset
# Out:
#                              dt  lowest_ask  highest_bid  \
# ts
# 1664820599  2022-10-03 18:09:59   19544.090    19544.080
# 1664820899  2022-10-03 18:14:59   19581.648    19581.640
# 1664821199  2022-10-03 18:19:59   19612.139    19612.130
# 1664821499  2022-10-03 18:24:59   19588.050    19588.041
# 1664821799  2022-10-03 18:29:59   19600.170    19600.160
# ...                         ...         ...          ...
# 1666136399  2022-10-18 23:39:59   19340.379    19340.371
# 1666136699  2022-10-18 23:44:59   19337.250    19337.240
# 1666136999  2022-10-18 23:49:59   19355.260    19355.250
# 1666137299  2022-10-18 23:54:59   19347.740    19347.730
# 1666137599  2022-10-18 23:59:59   19328.191    19328.180
#
#                                                          asks  \
# ts
# 1664820599  {'19544.09': 0.58, '19546.45': 0.205, '19547.4...
# 1664820899  {'19581.65': 0.55, '19584.63': 0.205, '19584.9...
# 1664821199  {'19612.14': 0.345, '19612.29': 0.5, '19612.30...
# 1664821499  {'19588.05': 0.41, '19590.01': 0.205, '19590.3...
# 1664821799  {'19600.17': 0.205, '19600.65': 0.41, '19602.7...
# ...                                                       ...
# 1666136399  {'19340.38': 0.365, '19341.86': 0.285, '19342....
# 1666136699  {'19337.25': 0.65, '19337.99': 0.025855, '1933...
# 1666136999  {'19355.26': 0.075, '19356.35': 0.285, '19358....
# 1666137299  {'19347.74': 0.645, '19351.34': 0.57, '19351.4...
# 1666137599  {'19328.19': 0.285, '19328.63': 0.08, '19329.7...
#
#                                                          bids   buy_vol  \
# ts
# 1664820599  {'19544.08': 0.41, '19543.10': 0.012791, '1954...  0.400852
# 1664820899  {'19581.64': 0.41, '19580.42': 0.7, '19579.09'...  0.382821
# 1664821199  {'19612.13': 0.41, '19611.45': 0.012747, '1960...  0.298041
# 1664821499  {'19588.04': 0.409134, '19587.52': 0.012761, '...  0.097272
# 1664821799  {'19600.16': 0.917754, '19599.96': 0.205, '195...  0.173571
# ...                                                       ...       ...
# 1666136399  {'19340.37': 0.08, '19340.18': 0.025852, '1933...  0.117265
# 1666136699  {'19337.24': 0.65, '19335.99': 0.285, '19335.0...  0.384377
# 1666136999  {'19355.25': 0.748326, '19353.73': 0.103336, '...  0.080143
# 1666137299  {'19347.73': 0.437526, '19347.47': 0.57, '1934...  0.171300
# 1666137599  {'19328.18': 0.65, '19326.40': 0.02587, '19325...  0.141797
#
#             sell_vol  total_vol  buy_num  sell_num  total_num
# ts
# 1664820599  0.466305   0.867157       20        27         47
# 1664820899  0.034063   0.416884       10        12         22
# 1664821199  0.795451   1.093492        9        30         39
# 1664821499  0.221801   0.319073        8        27         35
# 1664821799  0.894783   1.068354       10        16         26
# ...              ...        ...      ...       ...        ...
# 1666136399  0.623809   0.741074        2         7          9
# 1666136699  0.728422   1.112799        5        12         17
# 1666136999  0.082347   0.162490        3         4          7
# 1666137299  0.076446   0.247746        7         4         11
# 1666137599  0.458032   0.599829        3        12         15
#
# [4391 rows x 11 columns]

# %%
dataset = data_train

# %% [markdown]
# # Context

# %%
dpf = DataPointFactory(dataset, step_size=1, offset=50, observation_len=10, future_points=0)

context = BasicContext()
action_controller = ActionControllerDiffReward(context)
dp = dpf.get_current_step()
context.update_datapoint(dp)

# %% [markdown]
# # Класс фичи

# %%
"""
Module with basic features - deal status, rate, profit.
"""

import logging
import numpy as np
import pandas as pd

from core.observation_builder.features2.abstract_feature import AbstractFeature

logger = logging.getLogger(__name__)


class ProfitFeature2D(AbstractFeature):
    """Profit calculation"""
    def __init__(self, context, step_factor=(1,), scale_output=10):
        super().__init__(context)
        self.scale_output = scale_output
        self.step_factor = step_factor

    def _get(self):
        trade_state = self.context.get("is_open", domain="Trade")
        data_point = self.context.data_point
        trade = self.context.trade
        obs = []
        for sf in self.step_factor:
            timestamps = data_point.get_points(step_factor=sf)
            if trade_state:
                timestamps = data_point.get_points(step_factor=sf)
                mask = (timestamps > trade.open_ts) & (timestamps <= trade.close_ts)
                current_rates = data_point.get_values("highest_bid", step_factor=sf)
                current_rates = current_rates[sf - 1::sf]
                profit = current_rates / trade.open_price - 1 - trade.market_fee
                profit = profit * mask * self.scale_output
            else:
                profit = np.zeros(len(timestamps))

            obs.append(profit.reshape(-1, 1))

        feature = np.concatenate([*obs], axis=1)
        return featurevvz

# %% [markdown]
# # Perfomance test

# %%
def perfomance_test(dataset):
    dpf = DataPointFactory(dataset, step_size=1, offset=150, observation_len=30, future_points=0)
    dp = dpf.reset()
    done = False
    scale_factor = (1,3,5)
    
    feature = ProfitFeature2D(context, step_factor=scale_factor, scale_output=1)
    action_controller.apply_action(1)

    while not done:
        dp, done = dpf.get_next_step()
        obs = feature.get()
        
#cProfile.run("perfomance_test(dataset)")
# Out:
#          820594 function calls (817578 primitive calls) in 0.630 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.006    0.006    0.629    0.629 877656138.py:1(perfomance_test)
#      1505    0.003    0.000    0.012    0.000 <__array_function__ internals>:2(concatenate)
#         1    0.000    0.000    0.629    0.629 <string>:1(<module>)
#         1    0.000    0.000    0.000    0.000 __init__.py:1276(disable)
#         1    0.000    0.000    0.000    0.000 __init__.py:1424(debug)
#         1    0.000    0.000    0.000    0.000 __init__.py:1675(getEffectiveLevel)
#         1    0.000    0.000    0.000    0.000 __init__.py:1689(isEnabledFor)
#         1    0.000    0.000    0.000    0.000 __init__.py:218(_acquireLock)
#         1    0.000    0.000    0.000    0.000 __init__.py:227(_releaseLock)
#      1505    0.001    0.000    0.012    0.000 _methods.py:46(_sum)
#         1    0.000    0.000    0.000    0.000 abstract_feature.py:12(__init__)
#      1505    0.008    0.000    0.448    0.000 abstract_feature.py:16(get)
#         1    0.000    0.000    0.000    0.000 bad_action.py:7(__init__)
#      4515    0.001    0.000    0.001    0.000 base.py:326(ndim)
#      1507    0.002    0.000    0.005    0.000 base.py:3999(_validate_positional_slice)
#     10537    0.004    0.000    0.004    0.000 base.py:4786(values)
#      4515    0.006    0.000    0.006    0.000 base.py:4973(__contains__)
#      3014    0.004    0.000    0.007    0.000 base.py:5023(__getitem__)
#      1507    0.003    0.000    0.007    0.000 base.py:5071(_getitem_slice)
#      4521    0.003    0.000    0.003    0.000 base.py:6299(_validate_indexer)
#      1507    0.003    0.000    0.004    0.000 base.py:654(_simple_new)
#      1507    0.001    0.000    0.001    0.000 base.py:834(_reset_identity)
#      3016    0.002    0.000    0.002    0.000 base.py:884(__len__)
#         1    0.000    0.000    0.000    0.000 base_action.py:6(__init__)
#      1510    0.002    0.000    0.002    0.000 basic_context.py:51(get)
#      4515    0.003    0.000    0.008    0.000 blocks.py:209(external_values)
#      4515    0.003    0.000    0.005    0.000 blocks.py:2239(external_values)
#      7529    0.008    0.000    0.030    0.000 common.py:105(is_bool_indexer)
#      3014    0.002    0.000    0.003    0.000 common.py:160(cast_scalar_indexer)
#      7529    0.004    0.000    0.005    0.000 common.py:297(is_null_slice)
#     16559    0.005    0.000    0.007    0.000 common.py:346(apply_if_callable)
#      6022    0.002    0.000    0.002    0.000 contextlib.py:376(__init__)
#      6022    0.001    0.000    0.001    0.000 contextlib.py:379(__enter__)
#      6022    0.002    0.000    0.002    0.000 contextlib.py:382(__exit__)
#      1507    0.006    0.000    0.019    0.000 data_point.py:28(__init__)
#      9030    0.013    0.000    0.016    0.000 data_point.py:39(get_points)
#      4515    0.002    0.000    0.002    0.000 data_point.py:54(get_indexes)
#      4515    0.015    0.000    0.293    0.000 data_point.py:71(get_values)
#         1    0.000    0.000    0.000    0.000 dp_factory.py:20(__init__)
#         2    0.000    0.000    0.000    0.000 dp_factory.py:44(reset)
#      1507    0.006    0.000    0.174    0.000 dp_factory.py:54(get_current_step)
#      1505    0.002    0.000    0.176    0.000 dp_factory.py:65(get_next_step)
#      1507    0.002    0.000    0.002    0.000 flags.py:47(__init__)
#      1507    0.000    0.000    0.000    0.000 flags.py:51(allows_duplicate_labels)
#      1507    0.002    0.000    0.002    0.000 flags.py:83(allows_duplicate_labels)
#      4515    0.017    0.000    0.040    0.000 frame.py:3463(__getitem__)
#      4515    0.003    0.000    0.004    0.000 frame.py:3923(_get_item_cache)
#      1507    0.000    0.000    0.000    0.000 frame.py:578(_constructor)
#      1507    0.002    0.000    0.010    0.000 frame.py:587(__init__)
#      6022    0.004    0.000    0.004    0.000 frame.py:804(axes)
#      1508    0.002    0.000    0.006    0.000 frame.py:821(shape)
#      1507    0.005    0.000    0.007    0.000 generic.py:239(__init__)
#      1507    0.001    0.000    0.001    0.000 generic.py:328(attrs)
#      3014    0.001    0.000    0.001    0.000 generic.py:349(flags)
#      4515    0.007    0.000    0.053    0.000 generic.py:3722(xs)
#      1507    0.008    0.000    0.054    0.000 generic.py:3908(_slice)
#      1507    0.001    0.000    0.003    0.000 generic.py:3925(_set_is_copy)
#     16565    0.006    0.000    0.008    0.000 generic.py:43(_check)
#     22581    0.006    0.000    0.006    0.000 generic.py:546(_get_axis_number)
#      1507    0.006    0.000    0.009    0.000 generic.py:5517(__finalize__)
#      1507    0.001    0.000    0.001    0.000 generic.py:5577(__setattr__)
#     16559    0.013    0.000    0.017    0.000 generic.py:560(_get_axis)
#      1507    0.001    0.000    0.001    0.000 generic.py:566(_get_block_manager_axis)
#      7529    0.002    0.000    0.002    0.000 generic.py:660(ndim)
#      4515    0.002    0.000    0.003    0.000 indexing.py:1001(_validate_key)
#      4515    0.008    0.000    0.014    0.000 indexing.py:1023(_is_scalar_access)
#      4515    0.012    0.000    0.186    0.000 indexing.py:1137(_getitem_tuple)
#      4515    0.005    0.000    0.057    0.000 indexing.py:1151(_get_label)
#      4515    0.013    0.000    0.098    0.000 indexing.py:1169(_getitem_axis)
#      3014    0.001    0.000    0.001    0.000 indexing.py:130(iloc)
#      3014    0.002    0.000    0.016    0.000 indexing.py:1343(_validate_key)
#      1507    0.003    0.000    0.006    0.000 indexing.py:1419(_is_scalar_access)
#      3014    0.001    0.000    0.001    0.000 indexing.py:1432(<genexpr>)
#      1507    0.006    0.000    0.121    0.000 indexing.py:1456(_getitem_tuple)
#      1507    0.002    0.000    0.067    0.000 indexing.py:1487(_getitem_axis)
#      1507    0.003    0.000    0.064    0.000 indexing.py:1524(_get_slice_axis)
#     12044    0.006    0.000    0.011    0.000 indexing.py:2454(is_label_like)
#      1507    0.000    0.000    0.000    0.000 indexing.py:2468(need_slice)
#     10537    0.015    0.000    0.042    0.000 indexing.py:2481(check_deprecated_indexers)
#     18066    0.005    0.000    0.006    0.000 indexing.py:2486(<genexpr>)
#     18066    0.004    0.000    0.006    0.000 indexing.py:2497(<genexpr>)
#      4515    0.002    0.000    0.002    0.000 indexing.py:267(loc)
#      6022    0.004    0.000    0.011    0.000 indexing.py:740(_expand_ellipsis)
#     18066    0.003    0.000    0.003    0.000 indexing.py:745(<genexpr>)
#      1507    0.003    0.000    0.023    0.000 indexing.py:761(_validate_tuple_indexer)
#      6022    0.007    0.000    0.022    0.000 indexing.py:777(_is_nested_tuple_indexer)
#     18066    0.005    0.000    0.007    0.000 indexing.py:783(<genexpr>)
#      7529    0.003    0.000    0.004    0.000 indexing.py:804(_validate_key_length)
#      1507    0.005    0.000    0.076    0.000 indexing.py:815(_getitem_tuple_same_dim)
#      6022    0.030    0.000    0.177    0.000 indexing.py:834(_getitem_lowerdim)
#      6022    0.023    0.000    0.408    0.000 indexing.py:954(__getitem__)
#     18066    0.005    0.000    0.006    0.000 indexing.py:957(<genexpr>)
#     18066    0.009    0.000    0.014    0.000 indexing.py:958(<genexpr>)
#      7529    0.002    0.000    0.007    0.000 inference.py:184(is_array_like)
#      4515    0.002    0.000    0.003    0.000 inference.py:321(is_hashable)
#      4515    0.003    0.000    0.011    0.000 managers.py:1844(external_values)
#      1507    0.000    0.000    0.000    0.000 managers.py:919(__init__)
#      1505    0.000    0.000    0.000    0.000 multiarray.py:148(concatenate)
#         1    0.000    0.000    0.000    0.000 profit.py:16(__init__)
#      1505    0.097    0.000    0.426    0.000 profit.py:21(_get)
#      4515    0.004    0.000    0.015    0.000 series.py:645(values)
#         1    0.000    0.000    0.000    0.000 trade_controller.py:107(_get_penalty)
#         1    0.000    0.000    0.000    0.000 trade_controller.py:52(apply_action)
#         1    0.000    0.000    0.000    0.000 trade_controller.py:68(_action_open)
#      9030    0.002    0.000    0.005    0.000 utils.py:69(is_list_like_indexer)
#         1    0.000    0.000    0.000    0.000 uuid.py:138(__init__)
#         1    0.000    0.000    0.000    0.000 uuid.py:279(__str__)
#         1    0.000    0.000    0.000    0.000 uuid.py:713(uuid4)
#      1507    0.001    0.000    0.001    0.000 {built-in method __new__ of type object at 0x1067e8d58}
#      1507    0.001    0.000    0.001    0.000 {built-in method builtins.all}
#     24088    0.018    0.000    0.041    0.000 {built-in method builtins.any}
#     16559    0.002    0.000    0.002    0.000 {built-in method builtins.callable}
#         1    0.000    0.000    0.630    0.630 {built-in method builtins.exec}
#     18073    0.003    0.000    0.003    0.000 {built-in method builtins.getattr}
#      9030    0.002    0.000    0.002    0.000 {built-in method builtins.hash}
#    164102    0.030    0.000    0.038    0.000 {built-in method builtins.isinstance}
#      1507    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
# 24099/21083    0.005    0.000    0.007    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 {built-in method from_bytes}
#      1505    0.009    0.000    0.009    0.000 {built-in method numpy.core._multiarray_umath.implement_array_function}
#         1    0.000    0.000    0.000    0.000 {built-in method posix.urandom}
#         1    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.RLock' objects}
#      4515    0.001    0.000    0.001    0.000 {method 'append' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 {method 'count' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#      7535    0.001    0.000    0.001    0.000 {method 'get' of 'dict' objects}
#      1507    0.015    0.000    0.022    0.000 {method 'get_slice' of 'pandas._libs.internals.BlockManager' objects}
#      1505    0.012    0.000    0.012    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#         1    0.000    0.000    0.000    0.000 {method 'release' of '_thread.RLock' objects}
#      4515    0.004    0.000    0.004    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#      1505    0.001    0.000    0.014    0.000 {method 'sum' of 'numpy.ndarray' objects}
#      3014    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_float}
#      7535    0.001    0.000    0.001    0.000 {pandas._libs.lib.is_integer}
#     21074    0.003    0.000    0.003    0.000 {pandas._libs.lib.is_iterator}
#     16559    0.007    0.000    0.007    0.000 {pandas._libs.lib.is_list_like}
#      4515    0.005    0.000    0.005    0.000 {pandas._libs.lib.is_scalar}
#      9030    0.001    0.000    0.001    0.000 {pandas._libs.lib.item_from_zerodim}

# %%
profiler = cProfile.Profile()
profiler.enable()

perfomance_test(data_test2)

profiler.disable()

# %%
stats = pstats.Stats(profiler).sort_stats('tottime')
stats.print_stats()

# %% [markdown]
# # Оценка распределения

# %%
dataset = data_test2

done = False

dpf = DataPointFactory(dataset, step_size=1, offset=360, observation_len=30, future_points=0)
context = BasicContext()
step_factor = (1,3,12)
feature = ProfitFeature2D(context, step_factor=step_factor, scale_output=30)

dp = dpf.get_current_step()
context.update_datapoint(dp)
    
action_controller = ActionControllerDiffReward(context)

results = {}
num = 200
i = 0


while not done:
    dp, done = dpf.get_next_step()
    context.update_datapoint(dp)
    
    
    trade_is_open = context.get("is_open", domain="Trade")
    if i % num ==0:
        if trade_is_open:
            action_controller.apply_action(3)
        else:
            action_controller.apply_action(1)
    
    
    if trade_is_open:
        obs = feature.get()

        for sf_id in range(len(step_factor)):
            values = obs[:, sf_id]

            key_sf = f"sf-{step_factor[sf_id]}"
            if key_sf not in results:
                results[key_sf] = values
            else:
                results[key_sf] = np.concatenate([results[key_sf], values])
            
    i = i + 1

# %%
fig, ax = plt.subplots(figsize=(16,5), ncols=len(step_factor), nrows=1)

for sf_id in range(len(step_factor)):
    key_sf = f"sf-{step_factor[sf_id]}"
    values = results[key_sf]
    ax[sf_id].hist(values, bins=100)
    ax[sf_id].title.set_text(key_sf)
# Out:
# <img src="data:image/png;base64,..." width="1600">

# %%
feature = ProfitFeature2D(context, step_factor=(1,2,3))

# %%
obs = feature.get()
obs
# Out:
# array([[-0.00126779, -0.01837254, -0.0223732 ],
#        [-0.00129819, -0.01087517, -0.02477864],
#        [-0.00110984, -0.00127643, -0.01257718],
#        [-0.0011307 , -0.00120401, -0.00128369],
#        [ 0.        , -0.00056535, -0.00074685]], dtype=float32)

# %%
current_rate = dp.get_value("highest_bid").values[0]
current_rate
# Out:
# 23421.07

# %% [markdown]
# ## sf=1

# %%
dp.data.loc[1675453069:1675453309, "highest_bid"]/current_rate - 1
# Out:
# ts
# 1675453069   -0.000127
# 1675453129   -0.000130
# 1675453189   -0.000111
# 1675453249   -0.000113
# 1675453309    0.000000
# Name: highest_bid, dtype: float32

# %% [markdown]
# ## sf=2

# %%
obs = feature.get()
obs
# Out:
# array([[-0.00126779, -0.01837254, -0.0223732 ],
#        [-0.00129819, -0.01087517, -0.02477864],
#        [-0.00110984, -0.00127643, -0.01257718],
#        [-0.0011307 , -0.00120401, -0.00128369],
#        [ 0.        , -0.00056535, -0.00074685]], dtype=float32)

# %%
dp.data.tail(10)
# Out:
#                             dt    lowest_ask   highest_bid  \
# ts
# 1675452769 2023-02-03 22:32:49  23373.021484  23372.439453
# 1675452829 2023-02-03 22:33:49  23396.960938  23383.640625
# 1675452889 2023-02-03 22:34:49  23409.289062  23399.189453
# 1675452949 2023-02-03 22:35:49  23404.089844  23392.009766
# 1675453009 2023-02-03 22:36:49  23424.550781  23418.060547
# 1675453069 2023-02-03 22:37:49  23424.910156  23418.101562
# 1675453129 2023-02-03 22:38:49  23430.929688  23418.029297
# 1675453189 2023-02-03 22:39:49  23424.380859  23418.470703
# 1675453249 2023-02-03 22:40:49  23428.791016  23418.421875
# 1675453309 2023-02-03 22:41:49  23423.179688  23421.070312
#
#                                                          asks  \
# ts
# 1675452769  {'23373.02': 0.00035, '23378.43': 0.000379, '2...
# 1675452829  {'23396.96': 0.355256, '23396.97': 0.002065, '...
# 1675452889  {'23409.29': 0.373047, '23409.30': 0.002066, '...
# 1675452949  {'23404.09': 0.35958, '23404.10': 0.002056, '2...
# 1675453009  {'23424.55': 0.359278, '23424.56': 0.002097, '...
# 1675453069  {'23424.91': 0.359278, '23424.92': 0.002107, '...
# 1675453129  {'23430.93': 0.359625, '23430.94': 0.001289, '...
# 1675453189  {'23424.38': 0.001333, '23432.74': 0.002122, '...
# 1675453249  {'23428.79': 0.354612, '23428.80': 0.001272, '...
# 1675453309  {'23423.18': 0.001258, '23423.69': 0.363897, '...
#
#                                                          bids   buy_vol  \
# ts
# 1675452769  {'23372.44': 0.702901, '23372.43': 0.14, '2337...  0.023718
# 1675452829  {'23383.64': 0.674272, '23383.63': 0.001246, '...  0.015210
# 1675452889  {'23399.19': 0.14, '23399.18': 0.104425, '2339...  0.013877
# 1675452949  {'23392.01': 0.669712, '23392.00': 0.14, '2339...  0.008706
# 1675453009  {'23418.06': 0.66927, '23418.05': 0.059953, '2...  0.036118
# 1675453069  {'23418.10': 0.669269, '23418.09': 0.14, '2341...  0.021893
# 1675453129  {'23418.03': 0.669271, '23418.02': 0.09179, '2...  0.012593
# 1675453189  {'23418.47': 0.815634, '23418.44': 0.14, '2341...  0.044688
# 1675453249  {'23418.42': 0.673928, '23418.41': 0.640521, '...  0.017010
# 1675453309  {'23421.07': 0.664566, '23421.06': 0.004924, '...  0.000000
#
#             sell_vol  total_vol  buy_num  sell_num  total_num
# ts
# 1675452769  0.028416   0.052134        7         6         13
# 1675452829  0.016324   0.031534        3         7         10
# 1675452889  0.021983   0.035860        3         4          7
# 1675452949  0.019148   0.027854        3         3          6
# 1675453009  0.002416   0.038534        3         2          5
# 1675453069  0.000513   0.022406        3         1          4
# 1675453129  0.015364   0.027957        2         2          4
# 1675453189  0.008411   0.053099        9         4         13
# 1675453249  0.033221   0.050231        7         8         15
# 1675453309  0.006402   0.006402        0         2          2

# %%
avg = 23419.7459
avg/current_rate-1
# Out:
# -5.6547906749249144e-05

# %%
avg = 23418.25
avg/current_rate-1
# Out:
# -0.00012041774617344014
