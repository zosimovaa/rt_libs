# %% [markdown]
# # Imports

# %%
import sys
# for local development
RT_LIBS_PATH = "/Users/alex/Dev_projects/MyOwnRepo/rt_libs/src"
BA_LIBS_PATH = "/Users/alex/Dev_projects/MyOwnRepo/basic_application/src"
sys.path.append(RT_LIBS_PATH)
sys.path.append(BA_LIBS_PATH)

# %%
ALIAS = "test"


# %matplotlib notebook
db_connect_params = {
    "host" : "194.87.210.189",
    "port" : 59000,
    "user" : "alex",
    "password" : "Xrxcmr758",
    "database" : "rt5"
}

# %%
import time
import cProfile, pstats
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from data_providers import DbDataProviderRT5
from data_providers import ClickHouseConnector




from core_v2.observation_builder.precompute import PrecomputeOrderbookDiffFeature

from core_v2.action_controller import TrainController4Actions
from core_v2.context import Context
from core_v2.observation_builder.features import RatesFeature
# Out:
# 2023-09-22 19:43:58.426283: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# # Feature

# %%
"""
Module with basic features - deal status, rate, profit.
"""

import logging
import numpy as np
import pandas as pd

from core_v2.observation_builder.features import BaseFeature
from core_v2.data_point import DataPoint, DataPointFactory

logger = logging.getLogger(__name__)


class RatesFeature(BaseFeature):
    """Rates feature normalized with current rate"""

    def __init__(self, *args, **kwargs):
        self.price = kwargs.pop("price", "highest_bid")
        super().__init__(*args, **kwargs)

    def _get(self):
        data_point = self.context.get("data_point")
        current_price = self.context.get(self.price)
        data = data_point.get_values(self.price, step_factor=self.step_factor)
        feature = data / current_price - 1
        return feature
    
class RatesFeature2(BaseFeature):
    """Rates feature normalized with current rate"""

    def __init__(self, *args, **kwargs):
        self.price = kwargs.pop("price", "highest_bid")
        super().__init__(*args, **kwargs)

    def _get(self):
        data_point = self.context.get("data_point")
        current_price = self.context.get(self.price)
        data = data_point.get_values(self.price, step_factor=self.step_factor)
        
        values = data_point.get_values(self.price, step_factor=self.step_factor, num=-1)
        feature = data / np.mean(values) - 1
        return feature
    
    

class RatesDiffFeature(BaseFeature):

    def __init__(self, *args, **kwargs):
        self.price = kwargs.pop("price", "highest_bid")
        super().__init__(*args, **kwargs)

    def _get(self):
        data_point = self.context.get("data_point")
        current_price = self.context.get(self.price)

        data = data_point.get_values(self.price, step_factor=self.step_factor, num=dp.observation_len+1)
        data = data.diff()
        feature = data / current_price
            
        return feature

# %% [markdown]
# # Test dataset

# %%
class TestDatasetGenerator_v2:
    @staticmethod
    def make(features, num=30, idx_start=0, idx_step=1):
        idx_end = num * idx_step + idx_start
        idxs = np.arange(idx_start, idx_end, idx_step)

        data = []
        for feat in features:
            val_end = num * features[feat]["step"] + features[feat]["start"]
            data.append(np.arange(features[feat]["start"], val_end, features[feat]["step"])[:num].reshape(-1, 1))

        df = pd.DataFrame(np.concatenate(data, axis=1), columns=features.keys(), index=idxs)
        return df

# %%
#path = "/Users/alex/Dev_projects/RT/model_train/datasets/rt5/03.BTC_USDT-300-train.csv"
#dataset_real = pd.read_csv(path_train, index_col='ts')

# %% [markdown]
# # Test

# %%
import unittest
import time
import numpy as np

try:
    from tests.test_dataset import TestDatasetGenerator_v2
    from src.core_v2.data_point import DataPointFactoryV2, DataPointV2
    from src.core_v2.context import Context
    from src.core_v2.observation_builder.features import RatesFeature
    
except:
    from core_v2.data_point import DataPointFactory, DataPoint
    from core_v2.context import Context

class RatesFeatureTestCase(unittest.TestCase): 
    ALIAS = "unittests"
    OBSERVATION_LEN = 6
    STEP_FACTORS = (1, 2, 5)

    DF_NUM = 1000
    DF_FEATURES = {
        "lowest_ask": {"start": 101, "step": 1.01},
        "highest_bid": {"start": 100, "step": 1}
    }
    ASSERT_PRESISION = 5
    
    
    PERFOMANCE_CYCLES = 10000
    PERFOMANCE_MAX_DURATION = 1000

    def __init__(self, *args, **kwargs):
        super().__init__(*args, **kwargs)
    
        # test params
        self.context = Context(alias=self.ALIAS)
        self.dpf = DataPointFactory(
            TestDatasetGenerator_v2.make(self.DF_FEATURES, num=self.DF_NUM),
            step_size=1,
            offset=max(self.STEP_FACTORS) * self.OBSERVATION_LEN * 5,
            observation_len=self.OBSERVATION_LEN,
            future_points=0
        )
        
    def check_results(self, observed, expected):
        self.assertEqual(len(observed), len(expected))
        for i in range(len(expected)):
            self.assertEqual(np.round(observed[i], self.ASSERT_PRESISION), np.round(expected[i], self.ASSERT_PRESISION))


    def test_calculation(self):
        print(f"Test calculation")
        self.dpf.reset()
        dp = self.dpf.get_current_step()
        self.context.set_dp(dp)

        for sf in self.STEP_FACTORS:
            feature = RatesFeature(alias=self.ALIAS, step_factor=sf, scale_output=1)
            observed = feature.get()
            
            expected = dp.get_values("highest_bid", step_factor=sf)
            expected = expected/ dp.get_value("highest_bid") - 1

            self.check_results(observed, expected)
            
    def test_perfomance(self, wo_assert=False):
        print(f"Test perfomance")
        start_ts = time.time()
        
        
        for sf in self.STEP_FACTORS:
            feature = RatesFeature(alias=self.ALIAS, step_factor=sf, scale_output=1)
            done = True
            cycles = self.PERFOMANCE_CYCLES
            while cycles:
                cycles -= 1

                if done:
                    self.dpf.reset()

                dp, done = self.dpf.get_next_step()
                self.context.set_dp(dp)

                observed = feature.get()

        finish_ts = time.time()
        test_duration = np.round((finish_ts - start_ts) * 1000)
        print(f"Perfomance test duration: {test_duration}")
        perfomance_condition = test_duration < self.PERFOMANCE_MAX_DURATION
        if not wo_assert:
            self.assertEqual(perfomance_condition,True)

# %%
test = RatesFeatureTestCase()
test.test_calculation()
test.test_perfomance()
# Out:
# Test calculation
# 150
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Input In [47], in <cell line: 2>()
#       1 test = RatesFeatureTestCase()
# ----> 2 test.test_calculation()
#       3 test.test_perfomance()
#
# Input In [46], in RatesFeatureTestCase.test_calculation(self)
#      60 expected = dp.get_values("highest_bid", step_factor=sf)
#      61 expected = expected/ dp.get_value("highest_bid") - 1
# ---> 63 self.check_results(observed, expected)
#
# Input In [46], in RatesFeatureTestCase.check_results(self, observed, expected)
#      45 self.assertEqual(len(observed), len(expected))
#      46 for i in range(len(expected)):
# ---> 47     self.assertEqual(np.round(observed[i], self.ASSERT_PRESISION), np.round(expected[i], self.ASSERT_PRESISION))
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/unittest/case.py:837, in TestCase.assertEqual(self, first, second, msg)
#     833 """Fail if the two objects are unequal as determined by the '=='
#     834    operator.
#     835 """
#     836 assertion_func = self._getAssertEqualityFunc(first, second)
# --> 837 assertion_func(first, second, msg=msg)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/unittest/case.py:830, in TestCase._baseAssertEqual(self, first, second, msg)
#     828 standardMsg = '%s != %s' % _common_shorten_repr(first, second)
#     829 msg = self._formatMessage(msg, standardMsg)
# --> 830 raise self.failureException(msg)
#
# AssertionError: 0.39828 != -0.02008

# %%
dp = test.dpf.get_current_step()

# %% [markdown]
# # Profiling

# %%
profiler = cProfile.Profile()
profiler.enable()
test.test_perfomance(wo_assert=True)
#perfomance_test(data_test2)

profiler.disable()
# Out:
# Test perfomance
# Perfomance test duration: 1112.0

# %%
stats = pstats.Stats(profiler).sort_stats('cumtime')
stats.print_stats()
# Out:
#          1451875 function calls (1451874 primitive calls) in 1.113 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         2    0.000    0.000    1.113    0.556 /Users/alex/Dev_projects/venvs/env_rt_p39/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3361(run_code)
#         2    0.000    0.000    1.113    0.556 {built-in method builtins.exec}
#         1    0.000    0.000    1.113    1.113 /var/folders/sk/hq18v07n541fcm73_jz_p_k00000gn/T/ipykernel_66576/3978008238.py:3(<cell line: 3>)
#         1    0.042    0.042    1.113    1.113 /var/folders/sk/hq18v07n541fcm73_jz_p_k00000gn/T/ipykernel_66576/48649497.py:65(test_perfomance)
#     30000    0.023    0.000    0.671    0.000 /Users/alex/Dev_projects/MyOwnRepo/rt_libs/src/core_v2/observation_builder/features/base_feature.py:20(get)
#     30000    0.147    0.000    0.648    0.000 /var/folders/sk/hq18v07n541fcm73_jz_p_k00000gn/T/ipykernel_66576/3224509386.py:22(_get)
#     30000    0.074    0.000    0.477    0.000 /Users/alex/Dev_projects/MyOwnRepo/rt_libs/src/core_v2/data_point/data_point.py:73(get_values)
#     20000    0.018    0.000    0.331    0.000 <__array_function__ internals>:2(average)
# 20002/20001    0.017    0.000    0.310    0.000 {built-in method numpy.core._multiarray_umath.implement_array_function}
#     20000    0.027    0.000    0.293    0.000 /Users/alex/Dev_projects/venvs/env_rt_p39/lib/python3.9/site-packages/numpy/lib/function_base.py:280(average)
#     20000    0.012    0.000    0.263    0.000 {method 'mean' of 'numpy.ndarray' objects}
#     30000    0.081    0.000    0.260    0.000 /Users/alex/Dev_projects/MyOwnRepo/rt_libs/src/core_v2/context.py:35(set_dp)
#     20000    0.114    0.000    0.251    0.000 /Users/alex/Dev_projects/venvs/env_rt_p39/lib/python3.9/site-packages/numpy/core/_methods.py:162(_mean)
#     30000    0.027    0.000    0.137    0.000 /Users/alex/Dev_projects/MyOwnRepo/rt_libs/src/core_v2/data_point/dp_factory.py:68(get_next_step)
#     60000    0.054    0.000    0.117    0.000 /Users/alex/Dev_projects/MyOwnRepo/rt_libs/src/core_v2/data_point/data_point.py:86(get_value)
#     30435    0.077    0.000    0.112    0.000 /Users/alex/Dev_projects/MyOwnRepo/rt_libs/src/core_v2/data_point/dp_factory.py:54(get_current_step)
#     90000    0.048    0.000    0.080    0.000 /Users/alex/Dev_projects/venvs/env_rt_p39/lib/python3.9/site-packages/pandas/core/base.py:723(tolist)
#     20000    0.077    0.000    0.077    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#     20000    0.040    0.000    0.050    0.000 /Users/alex/Dev_projects/venvs/env_rt_p39/lib/python3.9/site-packages/numpy/core/_methods.py:66(_count_reduce_items)
#     90000    0.027    0.000    0.037    0.000 /Users/alex/Dev_projects/MyOwnRepo/rt_libs/src/core_v2/context.py:29(get)
#    150000    0.036    0.000    0.036    0.000 /Users/alex/Dev_projects/MyOwnRepo/rt_libs/src/core_v2/context.py:32(put)
#     30435    0.029    0.000    0.029    0.000 /Users/alex/Dev_projects/MyOwnRepo/rt_libs/src/core_v2/data_point/data_point.py:30(__init__)
#     30000    0.016    0.000    0.020    0.000 /Users/alex/Dev_projects/MyOwnRepo/rt_libs/src/core_v2/data_point/data_point.py:63(get_index_slice)
#     90000    0.020    0.000    0.020    0.000 {method 'tolist' of 'numpy.ndarray' objects}
#     90000    0.013    0.000    0.013    0.000 {method 'index' of 'list' objects}
#     90000    0.012    0.000    0.012    0.000 /Users/alex/Dev_projects/venvs/env_rt_p39/lib/python3.9/site-packages/pandas/core/indexes/base.py:4820(_values)
#     20000    0.012    0.000    0.012    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#     30000    0.011    0.000    0.011    0.000 /Users/alex/Dev_projects/MyOwnRepo/rt_libs/src/core_v2/data_point/data_point.py:97(get_current_index)
#     60000    0.010    0.000    0.010    0.000 /Users/alex/Dev_projects/MyOwnRepo/rt_libs/src/core_v2/data_point/data_point.py:52(_get_num)
#     90000    0.010    0.000    0.010    0.000 {method 'get' of 'dict' objects}
#     40004    0.008    0.000    0.008    0.000 {built-in method builtins.isinstance}
#     40000    0.006    0.000    0.006    0.000 {built-in method builtins.issubclass}
#     40000    0.006    0.000    0.006    0.000 {built-in method numpy.asanyarray}
#     30435    0.005    0.000    0.005    0.000 /Users/alex/Dev_projects/venvs/env_rt_p39/lib/python3.9/site-packages/pandas/core/indexes/base.py:4786(values)
#     20000    0.005    0.000    0.005    0.000 {built-in method numpy.core._multiarray_umath.normalize_axis_index}
#     20006    0.004    0.000    0.004    0.000 {built-in method builtins.getattr}
#     20000    0.003    0.000    0.003    0.000 /Users/alex/Dev_projects/venvs/env_rt_p39/lib/python3.9/site-packages/numpy/lib/function_base.py:276(_average_dispatcher)
#       435    0.000    0.000    0.002    0.000 /Users/alex/Dev_projects/MyOwnRepo/rt_libs/src/core_v2/data_point/dp_factory.py:44(reset)
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.print}
#         4    0.000    0.000    0.000    0.000 /Users/alex/Dev_projects/venvs/env_rt_p39/lib/python3.9/site-packages/ipykernel/iostream.py:535(write)
#         4    0.000    0.000    0.000    0.000 /Users/alex/Dev_projects/venvs/env_rt_p39/lib/python3.9/site-packages/ipykernel/iostream.py:465(_schedule_flush)
#         2    0.000    0.000    0.000    0.000 /Users/alex/Dev_projects/venvs/env_rt_p39/lib/python3.9/site-packages/ipykernel/iostream.py:203(schedule)
#         2    0.000    0.000    0.000    0.000 /Users/alex/Dev_projects/venvs/env_rt_p39/lib/python3.9/site-packages/zmq/sugar/socket.py:613(send)
#         2    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/codeop.py:142(__call__)
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.compile}
#         3    0.000    0.000    0.000    0.000 /var/folders/sk/hq18v07n541fcm73_jz_p_k00000gn/T/ipykernel_66576/3224509386.py:18(__init__)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(round_)
#         2    0.000    0.000    0.000    0.000 /Users/alex/Dev_projects/venvs/env_rt_p39/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3214(_update_code_co_name)
#         1    0.000    0.000    0.000    0.000 /Users/alex/Dev_projects/venvs/env_rt_p39/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3730(round_)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(around)
#         1    0.000    0.000    0.000    0.000 /Users/alex/Dev_projects/venvs/env_rt_p39/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3220(around)
#         1    0.000    0.000    0.000    0.000 /Users/alex/Dev_projects/venvs/env_rt_p39/lib/python3.9/site-packages/numpy/core/fromnumeric.py:51(_wrapfunc)
#         3    0.000    0.000    0.000    0.000 /Users/alex/Dev_projects/MyOwnRepo/rt_libs/src/core_v2/observation_builder/features/base_feature.py:13(__init__)
#         6    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#         1    0.000    0.000    0.000    0.000 /Users/alex/Dev_projects/venvs/env_rt_p39/lib/python3.9/site-packages/numpy/core/fromnumeric.py:38(_wrapit)
#         2    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/threading.py:1126(is_alive)
#         3    0.000    0.000    0.000    0.000 /Users/alex/Dev_projects/MyOwnRepo/rt_libs/src/core_v2/context.py:63(__init__)
#         2    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/contextlib.py:261(helper)
#         4    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/dis.py:449(findlinestarts)
#         4    0.000    0.000    0.000    0.000 /Users/alex/Dev_projects/venvs/env_rt_p39/lib/python3.9/site-packages/ipykernel/iostream.py:444(_is_master_process)
#         2    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/contextlib.py:114(__enter__)
#         2    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/contextlib.py:86(__init__)
#         2    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/threading.py:1059(_wait_for_tstate_lock)
#         2    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/contextlib.py:123(__exit__)
#         4    0.000    0.000    0.000    0.000 /Users/alex/Dev_projects/venvs/env_rt_p39/lib/python3.9/site-packages/IPython/core/compilerop.py:174(extra_flags)
#         1    0.000    0.000    0.000    0.000 {method 'round' of 'numpy.ndarray' objects}
#         3    0.000    0.000    0.000    0.000 /Users/alex/Dev_projects/MyOwnRepo/rt_libs/src/core_v2/context.py:11(__call__)
#         2    0.000    0.000    0.000    0.000 /Users/alex/Dev_projects/venvs/env_rt_p39/lib/python3.9/site-packages/traitlets/traitlets.py:692(__get__)
#         1    0.000    0.000    0.000    0.000 /var/folders/sk/hq18v07n541fcm73_jz_p_k00000gn/T/ipykernel_66576/3978008238.py:6(<cell line: 6>)
#         2    0.000    0.000    0.000    0.000 /Users/alex/Dev_projects/venvs/env_rt_p39/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3312(compare)
#         2    0.000    0.000    0.000    0.000 {method 'replace' of 'code' objects}
#         2    0.000    0.000    0.000    0.000 /Users/alex/Dev_projects/venvs/env_rt_p39/lib/python3.9/site-packages/ipykernel/iostream.py:90(_event_pipe)
#         4    0.000    0.000    0.000    0.000 {method 'write' of '_io.StringIO' objects}
#         6    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         2    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#         2    0.000    0.000    0.000    0.000 /Users/alex/Dev_projects/venvs/env_rt_p39/lib/python3.9/site-packages/traitlets/traitlets.py:654(get)
#         4    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#         4    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.RLock' objects}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#         2    0.000    0.000    0.000    0.000 {built-in method time.time}
#         2    0.000    0.000    0.000    0.000 /Users/alex/Dev_projects/venvs/env_rt_p39/lib/python3.9/site-packages/IPython/core/interactiveshell.py:1191(user_global_ns)
#         3    0.000    0.000    0.000    0.000 {method 'pop' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method numpy.asarray}
#         2    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#         2    0.000    0.000    0.000    0.000 /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/threading.py:529(is_set)
#         2    0.000    0.000    0.000    0.000 /Users/alex/Dev_projects/venvs/env_rt_p39/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3216(_around_dispatcher)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}

# %% [markdown]
# # Поиск производительности

# %%
dp = test.dpf.get_current_step()

# %%
# Запрос текущим методом
# %timeit dp.get_value("highest_bid")
# Out:
# 6.37 µs ± 148 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %%
# Сравнение с get_values
# %timeit dp.get_values("highest_bid")
# Out:
# 33.3 µs ± 371 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
# пробуем через loc
# %timeit dp.data.loc[:, "highest_bid"]
# Out:
# 27.3 µs ± 339 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
# пробуем через iloc
# %timeit dp.data.iloc[:, 1]
# Out:
# 116 µs ± 3.08 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
# прямой запрос к данные numpy (топчик!)
# %timeit dp.data.values[-1, 1]
# Out:
# 9.92 µs ± 117 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %%
# Запрос колонок происходит быстро
# %timeit dp.data.columns
# Out:
# 166 ns ± 2.39 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
# %timeit col_idx = dp.data.columns.tolist().index('highest_bid')
# Out:
# 1.74 µs ± 2.94 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %%
# Вычисление индекса - долго!
# %timeit col_idx = np.where(dp.data.columns == 'highest_bid')[0][0]
# Out:
# 60.5 µs ± 803 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
# %timeit col_idx = dp.data.index.tolist().index('highest_bid')

# %%
# %timeit data.index.tolist()[3:8]
# Out:
# 842 ns ± 2.41 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %%
dp.data.values.shape
# Out:
# (18, 2)

# %%
def perf_test(step_factor=1):
    col_idx = dp.data.columns.tolist().index('highest_bid')
    values = dp.data.values[-1*step_factor , col_idx]
    if step_factor>1:
        values = np.mean(values)
# %timeit perf_test(step_factor=1)
# Out:
# 13.6 µs ± 181 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# часть 2 - подготовка dp

# %%
cursor = 10
offset = 10
future_points=0

# %timeit data = test.dpf.dataset.iloc[cursor - offset : cursor + future_points, : ]
# Out:
# 56.8 µs ± 2.11 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
def perf_test(cursor = 10, offset = 10, future_points=0):
    values = test.dpf.dataset.values[cursor - offset : cursor + future_points, : ]
    columns=test.dpf.dataset.columns
    
    #df = pd.DataFrame(values, columns=columns) 
    
# %timeit perf_test()
# Out:
# 5.54 µs ± 149 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %%
columns=test.dpf.dataset.columns

# %%
columns.tolist().index('highest_bid')
# Out:
# 1

# %%
# Out:
#     lowest_ask  highest_bid
# 0       101.00        100.0
# 1       102.01        101.0
# 2       103.02        102.0
# 3       104.03        103.0
# 4       105.04        104.0
# ..         ...          ...
# 95      196.95        195.0
# 96      197.96        196.0
# 97      198.97        197.0
# 98      199.98        198.0
# 99      200.99        199.0
#
# [100 rows x 2 columns]

# %% [markdown]
# # Distributuion test

# %%
path = "/Users/alex/Dev_projects/RT/model_train/datasets/rt5/10.BTC_USDT-300.csv"
dataset_real = pd.read_csv(path, index_col='ts')

# %%
print(dataset_real.shape)
dataset_real.head()
# Out:
# (2879, 11)
#                              dt  lowest_ask  highest_bid  \
# ts
# 1674691799  2023-01-26 03:09:59   23133.291    23121.400
# 1674692099  2023-01-26 03:14:59   23107.590    23096.870
# 1674692399  2023-01-26 03:19:59   23092.379    23090.500
# 1674692699  2023-01-26 03:24:59   23093.000    23090.500
# 1674692999  2023-01-26 03:29:59   23075.410    23068.611
#
#                                                          asks  \
# ts
# 1674691799  {'23133.29': 1.108692, '23133.30': 0.205, '231...
# 1674692099  {'23107.59': 1.093986, '23107.60': 0.205, '231...
# 1674692399  {'23092.38': 1.092843, '23092.39': 0.002146, '...
# 1674692699  {'23093.00': 0.205, '23096.18': 0.432972, '231...
# 1674692999  {'23075.41': 1.119549, '23075.42': 0.14, '2307...
#
#                                                          bids   buy_vol  \
# ts
# 1674691799  {'23121.40': 0.015445, '23121.39': 0.059584, '...  0.180787
# 1674692099  {'23096.87': 0.030187, '23096.86': 0.001283, '...  0.085449
# 1674692399  {'23090.50': 0.036408, '23090.00': 4.5e-05, '2...  0.089454
# 1674692699  {'23090.50': 0.028784, '23090.00': 4.5e-05, '2...  0.153340
# 1674692999  {'23068.61': 0.000301, '23068.60': 0.051183, '...  0.161536
#
#             sell_vol  total_vol  buy_num  sell_num  total_num
# ts
# 1674691799  0.087755   0.268542       17        20         37
# 1674692099  0.054014   0.139463       16        16         32
# 1674692399  0.065574   0.155028       34        26         60
# 1674692699  0.122789   0.276129       38        32         70
# 1674692999  0.369253   0.530789       24        35         59

# %%
done = False
step_factors = (1,3,5)
observation_len = 30
offset = observation_len* max(step_factors) * 5

dpf = DataPointFactory(dataset_real, step_size=1, offset=offset, observation_len=observation_len, future_points=0)
context = Context(alias=ALIAS)


features = {}
for sf in step_factors:
    features[sf] = RatesFeature(alias=ALIAS, step_factor=sf, scale_output=1, clip_output=0, normalization=0)
    
dp = dpf.get_current_step()
context.set_dp(dp)
    
results = {}


while not done:
    dp, done = dpf.get_next_step()
    context.set_dp(dp)
    
    values = {}
    for sf in step_factors:
        values = features[sf].get()
        
        key_sf = f"sf-{sf}"
        if key_sf not in results:
            results[key_sf] = values
        else:
            results[key_sf] = np.concatenate([results[key_sf], values])
        

        
fig, ax = plt.subplots(figsize=(10,4), ncols=len(step_factors), nrows=1)

for sf_id in range(len(step_factors)):
    key_sf = f"sf-{step_factors[sf_id]}"
    values = results[key_sf]
    ax[sf_id].hist(values, bins=100)
    ax[sf_id].title.set_text(key_sf)
# Out:
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# 750
# 250
# 150
# <img src="data:image/png;base64,..." width="1000">

# %%
len(results["sf-1"])/observation_len
# Out:
# 2728.0

# %%
feature = Rates2D(context, step_factor=(1,2,3))

# %%
obs = feature.get()
obs
# Out:
# array([[-6.12807636e-04,  1.02689607e-03,  1.40421028e-03],
#        [-3.18772413e-04,  1.86177620e-04,  7.31015649e-04],
#        [-4.12531549e-04,  3.98346587e-04,  9.97257574e-04],
#        [-8.33366489e-04, -6.06320611e-04,  1.00793954e-03],
#        [-5.57884157e-04, -1.07470545e-03,  2.56900609e-04],
#        [-4.56686566e-04, -4.65790025e-04, -2.71431545e-04],
#        [-4.37657959e-04, -6.22949019e-04, -9.20739509e-04],
#        [-3.45974671e-06, -5.07285362e-04, -5.21556817e-04],
#        [-2.94078471e-06, -2.20558853e-04, -4.84076227e-04],
#        [ 0.00000000e+00, -1.47039235e-06, -2.13351047e-06]])

# %%
obs = feature.get()
obs
# Out:
# array([[-6.12807636e-04,  1.02689607e-03,  1.40421028e-03],
#        [-3.18772413e-04,  1.86177620e-04,  7.31015649e-04],
#        [-4.12531549e-04,  3.98346587e-04,  9.97257574e-04],
#        [-8.33366489e-04, -6.06320611e-04,  1.00793954e-03],
#        [-5.57884157e-04, -1.07470545e-03,  2.56900609e-04],
#        [-4.56686566e-04, -4.65790025e-04, -2.71431545e-04],
#        [-4.37657959e-04, -6.22949019e-04, -9.20739509e-04],
#        [-3.45974671e-06, -5.07285362e-04, -5.21556817e-04],
#        [-2.94078471e-06, -2.20558853e-04, -4.84076227e-04],
#        [ 0.00000000e+00, -1.47039235e-06, -2.13351047e-06]])

# %%
current_rate = dp.get_value("highest_bid")[0]
current_rate
# Out:
# 23123.08

# %% [markdown]
# ## sf=1

# %%
dp.data.loc[1675453069:1675453309, "highest_bid"]/current_rate - 1
# Out:
# Series([], Name: highest_bid, dtype: float64)

# %% [markdown]
# ## sf=2

# %%
obs = feature.get()
obs
# Out:
# array([[-0.00126779, -0.01837254, -0.0223732 ],
#        [-0.00129819, -0.01087517, -0.02477864],
#        [-0.00110984, -0.00127643, -0.01257718],
#        [-0.0011307 , -0.00120401, -0.00128369],
#        [ 0.        , -0.00056535, -0.00074685]], dtype=float32)

# %%
dp.data.tail(10)
# Out:
#                             dt    lowest_ask   highest_bid  \
# ts
# 1675452769 2023-02-03 22:32:49  23373.021484  23372.439453
# 1675452829 2023-02-03 22:33:49  23396.960938  23383.640625
# 1675452889 2023-02-03 22:34:49  23409.289062  23399.189453
# 1675452949 2023-02-03 22:35:49  23404.089844  23392.009766
# 1675453009 2023-02-03 22:36:49  23424.550781  23418.060547
# 1675453069 2023-02-03 22:37:49  23424.910156  23418.101562
# 1675453129 2023-02-03 22:38:49  23430.929688  23418.029297
# 1675453189 2023-02-03 22:39:49  23424.380859  23418.470703
# 1675453249 2023-02-03 22:40:49  23428.791016  23418.421875
# 1675453309 2023-02-03 22:41:49  23423.179688  23421.070312
#
#                                                          asks  \
# ts
# 1675452769  {'23373.02': 0.00035, '23378.43': 0.000379, '2...
# 1675452829  {'23396.96': 0.355256, '23396.97': 0.002065, '...
# 1675452889  {'23409.29': 0.373047, '23409.30': 0.002066, '...
# 1675452949  {'23404.09': 0.35958, '23404.10': 0.002056, '2...
# 1675453009  {'23424.55': 0.359278, '23424.56': 0.002097, '...
# 1675453069  {'23424.91': 0.359278, '23424.92': 0.002107, '...
# 1675453129  {'23430.93': 0.359625, '23430.94': 0.001289, '...
# 1675453189  {'23424.38': 0.001333, '23432.74': 0.002122, '...
# 1675453249  {'23428.79': 0.354612, '23428.80': 0.001272, '...
# 1675453309  {'23423.18': 0.001258, '23423.69': 0.363897, '...
#
#                                                          bids   buy_vol  \
# ts
# 1675452769  {'23372.44': 0.702901, '23372.43': 0.14, '2337...  0.023718
# 1675452829  {'23383.64': 0.674272, '23383.63': 0.001246, '...  0.015210
# 1675452889  {'23399.19': 0.14, '23399.18': 0.104425, '2339...  0.013877
# 1675452949  {'23392.01': 0.669712, '23392.00': 0.14, '2339...  0.008706
# 1675453009  {'23418.06': 0.66927, '23418.05': 0.059953, '2...  0.036118
# 1675453069  {'23418.10': 0.669269, '23418.09': 0.14, '2341...  0.021893
# 1675453129  {'23418.03': 0.669271, '23418.02': 0.09179, '2...  0.012593
# 1675453189  {'23418.47': 0.815634, '23418.44': 0.14, '2341...  0.044688
# 1675453249  {'23418.42': 0.673928, '23418.41': 0.640521, '...  0.017010
# 1675453309  {'23421.07': 0.664566, '23421.06': 0.004924, '...  0.000000
#
#             sell_vol  total_vol  buy_num  sell_num  total_num
# ts
# 1675452769  0.028416   0.052134        7         6         13
# 1675452829  0.016324   0.031534        3         7         10
# 1675452889  0.021983   0.035860        3         4          7
# 1675452949  0.019148   0.027854        3         3          6
# 1675453009  0.002416   0.038534        3         2          5
# 1675453069  0.000513   0.022406        3         1          4
# 1675453129  0.015364   0.027957        2         2          4
# 1675453189  0.008411   0.053099        9         4         13
# 1675453249  0.033221   0.050231        7         8         15
# 1675453309  0.006402   0.006402        0         2          2

# %%
avg = 23419.7459
avg/current_rate-1
# Out:
# -5.6547906749249144e-05

# %%
avg = 23418.25
avg/current_rate-1
# Out:
# -0.00012041774617344014

# %%
p =

# %%
step_factor = 3
s = dp.get_values("highest_bid", step_factor=step_factor)
s
# Out:
# array([23149.76 , 23164.309, 23152.58 , 23138.93 , 23139.19 , 23141.83 ,
#        23142.059, 23141.91 , 23154.45 , 23145.51 , 23151.53 , 23142.12 ,
#        23130.24 , 23124.53 , 23132.291, 23132.291, 23123.4  , 23094.72 ,
#        23094.709, 23101.75 , 23108.91 , 23115.709, 23113.541, 23103.81 ,
#        23110.18 , 23112.52 , 23112.96 , 23123.   , 23123.012, 23123.08 ])

# %%
s[step_factor-1::step_factor]
# Out:
# array([23152.58 , 23141.83 , 23154.45 , 23142.12 , 23132.291, 23094.72 ,
#        23108.91 , 23103.81 , 23112.96 , 23123.08 ])

# %%
s
# Out:
# array([23151.53 , 23142.12 , 23130.24 , 23124.53 , 23132.291, 23132.291,
#        23123.4  , 23094.72 , 23094.709, 23101.75 , 23108.91 , 23115.709,
#        23113.541, 23103.81 , 23110.18 , 23112.52 , 23112.96 , 23123.   ,
#        23123.012, 23123.08 ])
