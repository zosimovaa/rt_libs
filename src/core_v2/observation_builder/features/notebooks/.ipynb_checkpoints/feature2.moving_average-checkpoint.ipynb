# %%
import sys
# for local development
RT_LIBS_PATH = "/Users/alex/Dev_projects/MyOwnRepo/rt_libs/src"
BA_LIBS_PATH = "/Users/alex/Dev_projects/MyOwnRepo/basic_application/src"
sys.path.append(RT_LIBS_PATH)
sys.path.append(BA_LIBS_PATH)

# %%
ALIAS = "test"

# %matplotlib notebook
db_connect_params = {
    "host" : "194.87.210.189",
    "port" : 59000,
    "user" : "alex",
    "password" : "Xrxcmr758",
    "database" : "rt5"
}

# %%
import time
import cProfile, pstats
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from data_providers import DbDataProviderRT5
from data_providers import ClickHouseConnector

from core_v2.context import ContextConsumer, Context
from data_point import DataPoint, DataPointFactory

#from core_v2.action_controller import ActionControllerDiffReward

#from core.observation_builder.precompute import PrecomputeOrderbookDiffFeature

#from core.observation_builder.features2 import RatesFeature2D
# Out:
# 2023-09-17 22:18:32.134456: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ## Dataset

# %%
path_train = "/Users/alex/Dev_projects/RT/model_train/datasets/rt5/03.BTC_USDT-300-train.csv"
path_test = "/Users/alex/Dev_projects/RT/model_train/datasets/rt5/03.BTC_USDT-300-test.csv"
path_test2 = "/Users/alex/Dev_projects/RT/model_train/datasets/rt5/03.BTC_USDT-300-test2.csv"

data_train = pd.read_csv(path_train, index_col='ts')
data_test = pd.read_csv(path_test, index_col='ts')
data_test2 = pd.read_csv(path_test2, index_col='ts')

# %%
try:
    dataset = pd.read_csv("./test_dataset.csv", index_col='ts')
    print("Прочитано из файла")
except FileNotFoundError:
    
    ts = int(time.time())
    period = 60
    total_points = 5000

    pair = "BTC_USDT"


    #----
    with ClickHouseConnector(db_connect_params) as conn:
        data_provider = DbDataProviderRT5(conn)

        dataset = data_provider.get(
                                ts,
                                period,
                                total_points,
                                pair
                            )
    dataset.to_csv("./test_dataset.csv")
    print("Загружен новый датасет")
    
print(dataset.shape)
# Out:
# Прочитано из файла
# (5000, 11)

# %%
dataset.index.values
# Out:
# array([1675190531, 1675190591, 1675190651, ..., 1675490351, 1675490411,
#        1675490471])

# %%
dataset = data_train

# %% [markdown]
# # Feature

# %%
"""
Module with basic features_del - deal status, rate, profit.
"""

import logging
import numpy as np
import pandas as pd

from core_v2.observation_builder.features import BaseFeature

logger = logging.getLogger(__name__)

def moving_average(a, n=2):
    ret = np.cumsum(a, dtype=np.float32)
    ret[n:] = ret[n:] - ret[:-n]
    return ret[n - 1:] / n


class MovingAverageFeature(BaseFeature):
    """Rates feature normalized with current rate"""

    def __init__(self, *args, **kwargs):
        self.ma_points = kwargs.pop("ma_points", 1)
        self.feature = kwargs.pop("feature", "highest_bid")

        super().__init__(*args, **kwargs)

    def _get(self):
        data_point = self.context.get("data_point")
        num = data_point.observation_len + self.step_factor - 1
        data = data_point.get_values(self.feature, step_factor=self.step_factor, num=num)

        feature = np.average(data.reshape(-1, self.step_factor), axis=1)
        feature = moving_average(feature, n=self.ma_points)

        # нормализуем.... надо протестить как это будет выглядеть
        #feature = feature/feature[-1] - 1

        return feature

# %% [markdown]
# # Test

# %%
# params
observation_len = 8
step_factors = (1, 8)
offset = max(step_factors)*observation_len
scale_output = 1

# %%
# dataset
start_idx = 1000
start_value = 100

idx = np.arange(start_idx, start_idx+observation_len*max(step_factors), 1)
data = np.arange(start_value, start_value+observation_len*max(step_factors), 1).reshape(-1,1)

data = np.concatenate([data, data* 1.01], axis=1).reshape(len(data), 2)
dataset = pd.DataFrame(data, columns=["highest_bid", "lowest_ask"], index=idx)
display(dataset.tail(3))
print(dataset.shape)
# Out:
#       highest_bid  lowest_ask
# 1061        161.0      162.61
# 1062        162.0      163.62
# 1063        163.0      164.63
# (64, 2)

# %%
dpf = DataPointFactory(dataset, step_size=1, offset=offset, observation_len=observation_len, future_points=0)
dp = dpf.get_current_step()
context = Context(alias=ALIAS)
context.set_dp(dp)

# %%
"""
Module with basic features_del - deal status, rate, profit.
"""

import logging
import numpy as np
import pandas as pd

from core_v2.observation_builder.features import BaseFeature

logger = logging.getLogger(__name__)

def moving_average(a, n=2):
    ret = np.cumsum(a, dtype=np.float32)
    ret[n:] = ret[n:] - ret[:-n]
    return ret[n - 1:] / n


class MovingAverageFeature(BaseFeature):
    """Rates feature normalized with current rate"""

    def __init__(self, *args, **kwargs):
        self.ma_points = kwargs.pop("ma_points", 1)
        self.feature = kwargs.pop("feature", "highest_bid")

        super().__init__(*args, **kwargs)

    def _get(self):
        data_point = self.context.get("data_point")
        num = data_point.observation_len + self.ma_points - 1
        current_value = data_point.get_value(self.feature)[0]
        
        
        data = data_point.get_values(self.feature, step_factor=self.step_factor, num=num)
        
        feature = np.average(data.reshape(-1, self.step_factor), axis=1)
        feature = moving_average(feature, n=self.ma_points)

        # нормализуем.... надо протестить как это будет выглядеть
        feature = feature/current_value - 1

        return feature

# %%
ma_points = 3
step_factor = 1

# %%
# observed
feature = MovingAverageFeature(alias=ALIAS, step_factor=step_factor, scale_output=1, ma_points=ma_points)
val_obs = feature.get()

# %%
# Expected
df = dp.data
df.tail(3)
# Out:
#       highest_bid  lowest_ask
# 1061        161.0      162.61
# 1062        162.0      163.62
# 1063        163.0      164.63

# %%
val_exp = df["highest_bid"].rolling(ma_points).mean()
val_exp = val_exp/df.loc[max(df.index), "highest_bid"]-1
val_exp = val_exp.values[-observation_len:]

val_exp
# Out:
# array([-0.04907975, -0.04294479, -0.03680982, -0.03067485, -0.02453988,
#        -0.01840491, -0.01226994, -0.00613497])

# %%
sum(val_obs - val_exp)
# Out:
# -3.5835921341487165e-08

# %% [markdown]
# # Context

# %%
dpf = DataPointFactory(dataset, step_size=1, offset=1000, observation_len=50, future_points=0)
dp = dpf.get_current_step()
context = Context(alias="test")
context.set_dp(dp)

# %%
context

# %% [markdown]
# # Исследование

# %%
def moving_average(a, n=2):
    ret = np.cumsum(a, dtype=np.float32)
    ret[n:] = ret[n:] - ret[:-n]
    return ret[n - 1:] / n

# %%
obs_len = 50 # длина наблюдения для теста

vals = dp.get_values("highest_bid", step_factor=1, num=obs_len + ma_len - 1)
print(len(vals))
print(vals)
# Out:
# 59
# [19907.959 19895.16  19901.691 19884.121 19905.422 19884.979 19863.22
#  19855.34  19872.9   19890.19  19884.21  19849.25  19806.83  19809.13
#  19830.111 19789.139 19788.24  19733.719 19706.05  19690.    19693.84
#  19743.77  19748.85  19788.262 19775.271 19791.879 19825.16  19799.531
#  19820.25  19850.14  19829.781 19872.34  19834.14  19810.85  19793.92
#  19808.37  19813.59  19805.969 19820.441 19801.99  19823.89  19829.25
#  19842.73  19776.94  19779.25  19746.91  19740.83  19729.541 19728.629
#  19747.281 19760.139 19763.7   19758.75  19771.53  19715.488 19231.049
#  19214.71  19119.15  19058.83 ]

# %%
obs_len = 10
sf = 2


ma_len_1 = 3
ma_vals_1 = dp.get_values("highest_bid", step_factor=sf, num=obs_len + ma_len_1 - 1)
ma_1 = moving_average(ma_vals_1, n=ma_len_1)
#print(vals_ma)

ma_len_2 = 10
ma_vals_2 = dp.get_values("highest_bid", step_factor=sf, num=obs_len + ma_len_2 - 1)
ma_2 = moving_average(ma_vals_2, n=ma_len_2)
#print(vals_ma2)



vals = dp.get_values("highest_bid", step_factor=sf, num=obs_len)

# %%
fig, ax = plt.subplots(figsize=(10,4))
ax.plot(vals)
ax.plot(ma_1)
ax.plot(ma_2)
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
res = []
    for i in range(data_point.observation_len):
        val = feature[self.step_factor * i: self.step_factor * (i + 1)]
        res.append(val.mean())
    feature = np.array(res).reshape(-1, 1)

# %%
ma_lem
# Out:
# 20

# %%
(obs_len+ma_len-1)%2
# Out:
# 1

# %%
sf = 5
ma_len = 3


# Количество точек в наблюдении для ориентира
vals_1 = dp.get_values("highest_bid", step_factor=1, num=obs_len)
print(f"Количество элементов в наблюдении: {len(vals_1)}")

# Получаем точки для данного sf
ma_vals_1 = dp.get_values("highest_bid", step_factor=sf, num=obs_len+ma_len-1)
print(f"Количество элементов для SF={sf}: {len(ma_vals_1)}")

# среднее по соседним 2 элементам - На выходе должно быть количество obs_len + ma_len-1
avgResult = np.average(ma_vals_1.reshape(-1, sf), axis=1)
print(f"Количество элементов для построения MA: {len(avgResult)}")

ma = moving_average(avgResult, n=ma_len)
print(f"Количество элементов MA: {len(ma)}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [91], in <cell line: 6>()
#       2 ma_len = 3
#       5 # Количество точек в наблюдении для ориентира
# ----> 6 vals_1 = dp.get_values("highest_bid", step_factor=1, num=obs_len)
#       7 print(f"Количество элементов в наблюдении: {len(vals_1)}")
#       9 # Получаем точки для данного sf
#
# NameError: name 'obs_len' is not defined

# %%
dpf = DataPointFactory(dataset, step_size=1, offset=1000, observation_len=50, future_points=0)
dp = dpf.get_current_step()
context = Context(alias="test")
context.set_dp(dp)

# %%
step_factor=2

feature = dp.get_values("highest_bid", step_factor=step_factor)

# %%
avgResult = np.average(feature.reshape(-1, step_factor), axis=1)
len(avgResult)
avgResult
# Out:
# array([19984.97  , 19943.97  , 19902.9945, 19913.25  , 19929.4355,
#        19911.875 , 19942.815 , 19985.93  , 19958.8055, 19919.975 ,
#        19924.7   , 19908.705 , 19931.009 , 19918.3545, 19901.245 ,
#        19892.83  , 19896.54  , 19928.325 , 19941.52  , 19958.835 ,
#        19932.7095, 19898.4255, 19894.7715, 19874.0995, 19864.12  ,
#        19887.2   , 19828.04  , 19819.6205, 19788.6895, 19719.8845,
#        19691.92  , 19746.31  , 19781.7665, 19808.5195, 19809.8905,
#        19839.9605, 19853.24  , 19802.385 , 19810.98  , 19813.205 ,
#        19812.94  , 19835.99  , 19778.095 , 19743.87  , 19729.085 ,
#        19753.71  , 19761.225 , 19743.509 , 19222.8795, 19088.99  ])

# %%
res = []
for i in range(dp.observation_len):
    val = feature[step_factor * i: step_factor * (i + 1)]
    res.append(val.mean())
#res = np.array(res).reshape(-1, 1)

len(res)
res
# Out:
# [19984.97,
#  19943.97,
#  19902.9945,
#  19913.25,
#  19929.4355,
#  19911.875,
#  19942.815000000002,
#  19985.93,
#  19958.805500000002,
#  19919.975,
#  19924.699999999997,
#  19908.705,
#  19931.009,
#  19918.3545,
#  19901.245000000003,
#  19892.83,
#  19896.54,
#  19928.325,
#  19941.52,
#  19958.835,
#  19932.709499999997,
#  19898.425499999998,
#  19894.7715,
#  19874.0995,
#  19864.120000000003,
#  19887.199999999997,
#  19828.04,
#  19819.6205,
#  19788.6895,
#  19719.8845,
#  19691.92,
#  19746.309999999998,
#  19781.766499999998,
#  19808.519500000002,
#  19809.8905,
#  19839.9605,
#  19853.239999999998,
#  19802.385,
#  19810.98,
#  19813.205,
#  19812.940000000002,
#  19835.989999999998,
#  19778.095,
#  19743.870000000003,
#  19729.085,
#  19753.71,
#  19761.225,
#  19743.509,
#  19222.8795,
#  19088.99]

# %%
print(f"Наблюдение: {vals_1}")
print(f"Элементы для SF={sf}: {ma_vals_1}")
print(f"Элементы для построения MA: {ma_vals_1}")
print(f"Элементы MA: {ma}")
# Out:
# Наблюдение: [19747.281 19760.139 19763.7   19758.75  19771.53  19715.488 19231.049
#  19214.71  19119.15  19058.83 ]
# Элементы для SF=5: [19905.422 19884.979 19863.22  19855.34  19872.9   19890.19  19884.21
#  19849.25  19806.83  19809.13  19830.111 19789.139 19788.24  19733.719
#  19706.05  19690.    19693.84  19743.77  19748.85  19788.262 19775.271
#  19791.879 19825.16  19799.531 19820.25  19850.14  19829.781 19872.34
#  19834.14  19810.85  19793.92  19808.37  19813.59  19805.969 19820.441
#  19801.99  19823.89  19829.25  19842.73  19776.94  19779.25  19746.91
#  19740.83  19729.541 19728.629 19747.281 19760.139 19763.7   19758.75
#  19771.53  19715.488 19231.049 19214.71  19119.15  19058.83 ]
# Элементы для построения MA: [19905.422 19884.979 19863.22  19855.34  19872.9   19890.19  19884.21
#  19849.25  19806.83  19809.13  19830.111 19789.139 19788.24  19733.719
#  19706.05  19690.    19693.84  19743.77  19748.85  19788.262 19775.271
# ...

# %% [markdown]
# ### Про степфактор

# %%
dpf2 = DataPointFactory(dataset, step_size=1, offset=30, observation_len=10, future_points=0)
dp2 = dpf2.get_current_step()
context2 = Context(alias="test_sf")
context2.set_dp(dp2)

# %%
dp2.data["highest_bid"].values
# Out:
# array([19928.361, 19913.   , 19908.92 , 19826.23 , 19858.441, 19888.23 ,
#        19876.55 , 19869.979, 19898.2  , 19884.28 , 19892.229, 19892.229,
#        19873.38 , 19892.61 , 19890.25 , 19901.209, 19900.02 , 19893.91 ,
#        19881.531, 19861.81 , 19835.45 , 19762.68 , 19797.521, 19803.83 ,
#        19834.96 , 19792.451, 19818.8  , 19803.82 , 19850.701, 19823.441])

# %%
vals_sf1 = dp2.get_values("highest_bid", step_factor=1)
print(len(vals_sf1))
vals_sf1
# Out:
# 10
# array([19835.45 , 19762.68 , 19797.521, 19803.83 , 19834.96 , 19792.451,
#        19818.8  , 19803.82 , 19850.701, 19823.441])

# %%
vals_sf2 = dp2.get_values("highest_bid", step_factor=2)
print(len(vals_sf2))
vals_sf2
# Out:
# 20
# array([19892.229, 19892.229, 19873.38 , 19892.61 , 19890.25 , 19901.209,
#        19900.02 , 19893.91 , 19881.531, 19861.81 , 19835.45 , 19762.68 ,
#        19797.521, 19803.83 , 19834.96 , 19792.451, 19818.8  , 19803.82 ,
#        19850.701, 19823.441])

# %%
vals_sf3 = dp2.get_values("highest_bid", step_factor=3)
print(len(vals_sf3))
vals_sf3
# Out:
# 30
# array([19928.361, 19913.   , 19908.92 , 19826.23 , 19858.441, 19888.23 ,
#        19876.55 , 19869.979, 19898.2  , 19884.28 , 19892.229, 19892.229,
#        19873.38 , 19892.61 , 19890.25 , 19901.209, 19900.02 , 19893.91 ,
#        19881.531, 19861.81 , 19835.45 , 19762.68 , 19797.521, 19803.83 ,
#        19834.96 , 19792.451, 19818.8  , 19803.82 , 19850.701, 19823.441])

# %% [markdown]
# # Feature

# %%
"""
Module with basic features - deal status, rate, profit.
"""

import logging
import numpy as np
import pandas as pd

from core.observation_builder.features2.abstract_feature import AbstractFeature

logger = logging.getLogger(__name__)


class RatesFeature2D(AbstractFeature):
    """Returns a matrix with normalized rates for different periods"""

    def __init__(self, context, step_factor=(1,), scale_output=30):
        super().__init__(context, step_factor=step_factor, scale_output=scale_output)

    def _get(self):
        data_point = self.context.data_point
        current_price = data_point.get_value("highest_bid")
        current_price = current_price[0]
        obs = []
        for sf in self.step_factor:
            feature = data_point.get_values("highest_bid", step_factor=sf, num=data_point.observation_len+1)
            feature = np.diff(feature)
            feature = (feature / current_price) * self.scale_output

            if sf > 1:
                res = []
                for i in range(data_point.observation_len):
                    val = feature[sf * i: sf * (i + 1)]
                    res.append(val.mean())
                feature = np.array(res).reshape(-1, 1)
            else:
                feature = feature.reshape(-1, 1)
            obs.append(feature)
        feature = np.concatenate([*obs], axis=1)
        return feature

# %% [markdown]
# # Perfomance test

# %%
def perfomance_test(dataset):
    dpf = DataPointFactory(dataset, step_size=1, offset=150, observation_len=30, future_points=0)
    dp = dpf.reset()
    done = False
    scale_factor = (1,3,5)
    
    feature = RatesFeature2D(context, step_factor=scale_factor, scale_factor=1)

    while not done:
        dp, done = dpf.get_next_step()
        obs = feature.get()
        
#cProfile.run("perfomance_test(dataset)")

# %%
profiler = cProfile.Profile()
profiler.enable()

perfomance_test(data_test2)

profiler.disable()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [12], in <cell line: 4>()
#       1 profiler = cProfile.Profile()
#       2 profiler.enable()
# ----> 4 perfomance_test(data_test2)
#       6 profiler.disable()
#
# Input In [11], in perfomance_test(dataset)
#       4 done = False
#       5 scale_factor = (1,3,5)
# ----> 7 feature = RatesFeature2D(context, step_factor=scale_factor, scale_factor=1)
#       9 while not done:
#      10     dp, done = dpf.get_next_step()
#
# TypeError: __init__() got an unexpected keyword argument 'scale_factor'

# %%
stats = pstats.Stats(profiler).sort_stats('tottime')
stats.print_stats()

# %% [markdown]
# # Оценка распределения

# %%
dataset = data_test

done = False

dpf = DataPointFactory(dataset, step_size=1, offset=360, observation_len=30, future_points=0)
context = BasicContext()
step_factor = (1,3,6)
feature = RatesFeature2D(context, step_factor=step_factor, scale_output=120)

dp = dpf.get_current_step()
context.update_datapoint(dp)
    
action_controller = ActionControllerDiffReward(context)

results = {}



while not done:
    dp, done = dpf.get_next_step()
    context.update_datapoint(dp)
    
    
    trade_is_open = context.get("is_open", domain="Trade")

    obs = feature.get(clip_edge=3)

    for sf_id in range(len(step_factor)):
        values = obs[:, sf_id]

        key_sf = f"sf-{step_factor[sf_id]}"
        if key_sf not in results:
            results[key_sf] = values
        else:
            results[key_sf] = np.concatenate([results[key_sf], values])

# %%
fig, ax = plt.subplots(figsize=(16,5), ncols=len(step_factor), nrows=1)

for sf_id in range(len(step_factor)):
    key_sf = f"sf-{step_factor[sf_id]}"
    values = results[key_sf]
    ax[sf_id].hist(values, bins=100)
    ax[sf_id].title.set_text(key_sf)
# Out:
# <img src="data:image/png;base64,..." width="1600">

# %%
feature = Rates2D(context, step_factor=(1,2,3))

# %%
obs = feature.get()
obs
# Out:
# array([[-6.12807636e-04,  1.02689607e-03,  1.40421028e-03],
#        [-3.18772413e-04,  1.86177620e-04,  7.31015649e-04],
#        [-4.12531549e-04,  3.98346587e-04,  9.97257574e-04],
#        [-8.33366489e-04, -6.06320611e-04,  1.00793954e-03],
#        [-5.57884157e-04, -1.07470545e-03,  2.56900609e-04],
#        [-4.56686566e-04, -4.65790025e-04, -2.71431545e-04],
#        [-4.37657959e-04, -6.22949019e-04, -9.20739509e-04],
#        [-3.45974671e-06, -5.07285362e-04, -5.21556817e-04],
#        [-2.94078471e-06, -2.20558853e-04, -4.84076227e-04],
#        [ 0.00000000e+00, -1.47039235e-06, -2.13351047e-06]])

# %%
obs = feature.get()
obs
# Out:
# array([[-6.12807636e-04,  1.02689607e-03,  1.40421028e-03],
#        [-3.18772413e-04,  1.86177620e-04,  7.31015649e-04],
#        [-4.12531549e-04,  3.98346587e-04,  9.97257574e-04],
#        [-8.33366489e-04, -6.06320611e-04,  1.00793954e-03],
#        [-5.57884157e-04, -1.07470545e-03,  2.56900609e-04],
#        [-4.56686566e-04, -4.65790025e-04, -2.71431545e-04],
#        [-4.37657959e-04, -6.22949019e-04, -9.20739509e-04],
#        [-3.45974671e-06, -5.07285362e-04, -5.21556817e-04],
#        [-2.94078471e-06, -2.20558853e-04, -4.84076227e-04],
#        [ 0.00000000e+00, -1.47039235e-06, -2.13351047e-06]])

# %%
current_rate = dp.get_value("highest_bid")[0]
current_rate
# Out:
# 23123.08

# %% [markdown]
# ## sf=1

# %%
dp.data.loc[1675453069:1675453309, "highest_bid"]/current_rate - 1
# Out:
# Series([], Name: highest_bid, dtype: float64)

# %% [markdown]
# ## sf=2

# %%
obs = feature.get()
obs
# Out:
# array([[-0.00126779, -0.01837254, -0.0223732 ],
#        [-0.00129819, -0.01087517, -0.02477864],
#        [-0.00110984, -0.00127643, -0.01257718],
#        [-0.0011307 , -0.00120401, -0.00128369],
#        [ 0.        , -0.00056535, -0.00074685]], dtype=float32)

# %%
dp.data.tail(10)
# Out:
#                             dt    lowest_ask   highest_bid  \
# ts
# 1675452769 2023-02-03 22:32:49  23373.021484  23372.439453
# 1675452829 2023-02-03 22:33:49  23396.960938  23383.640625
# 1675452889 2023-02-03 22:34:49  23409.289062  23399.189453
# 1675452949 2023-02-03 22:35:49  23404.089844  23392.009766
# 1675453009 2023-02-03 22:36:49  23424.550781  23418.060547
# 1675453069 2023-02-03 22:37:49  23424.910156  23418.101562
# 1675453129 2023-02-03 22:38:49  23430.929688  23418.029297
# 1675453189 2023-02-03 22:39:49  23424.380859  23418.470703
# 1675453249 2023-02-03 22:40:49  23428.791016  23418.421875
# 1675453309 2023-02-03 22:41:49  23423.179688  23421.070312
#
#                                                          asks  \
# ts
# 1675452769  {'23373.02': 0.00035, '23378.43': 0.000379, '2...
# 1675452829  {'23396.96': 0.355256, '23396.97': 0.002065, '...
# 1675452889  {'23409.29': 0.373047, '23409.30': 0.002066, '...
# ...

# %%
avg = 23419.7459
avg/current_rate-1
# Out:
# -5.6547906749249144e-05

# %%
avg = 23418.25
avg/current_rate-1
# Out:
# -0.00012041774617344014

# %%
p =

# %%
step_factor = 3
s = dp.get_values("highest_bid", step_factor=step_factor)
s
# Out:
# array([23149.76 , 23164.309, 23152.58 , 23138.93 , 23139.19 , 23141.83 ,
#        23142.059, 23141.91 , 23154.45 , 23145.51 , 23151.53 , 23142.12 ,
#        23130.24 , 23124.53 , 23132.291, 23132.291, 23123.4  , 23094.72 ,
#        23094.709, 23101.75 , 23108.91 , 23115.709, 23113.541, 23103.81 ,
#        23110.18 , 23112.52 , 23112.96 , 23123.   , 23123.012, 23123.08 ])

# %%
s[step_factor-1::step_factor]
# Out:
# array([23152.58 , 23141.83 , 23154.45 , 23142.12 , 23132.291, 23094.72 ,
#        23108.91 , 23103.81 , 23112.96 , 23123.08 ])

# %%
s
# Out:
# array([23151.53 , 23142.12 , 23130.24 , 23124.53 , 23132.291, 23132.291,
#        23123.4  , 23094.72 , 23094.709, 23101.75 , 23108.91 , 23115.709,
#        23113.541, 23103.81 , 23110.18 , 23112.52 , 23112.96 , 23123.   ,
#        23123.012, 23123.08 ])
